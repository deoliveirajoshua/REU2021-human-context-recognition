# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
import random
import csv
from prettytable import PrettyTable
from pylab import *
from scipy.stats import wasserstein_distance
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.utils.data import Dataset

dev = ""

if torch.cuda.is_available():  
  dev = "cuda:0" 
else:  
  dev = "cpu"  
device = torch.device(dev)

# %% [markdown]
# # Change directory

# %%
os.chdir('/Users/maryclaremartin/Documents/jup/ExtraSensory')

# %% [markdown]
# # Interpolating acceleration columns with average values

# %%
#replaces Nan values with average values
#df: data frame of data to use
def interpolation(df):
    col_to_avg = list(df.columns) #Start with keeping all the columns as columns to use an average interpolation on
    for k in range(len(list(df.columns))):
        if list(df.columns)[k].startswith(('discrete', 'label')): #Remove label and discrete columns from col_to_avg
            col_to_avg.remove(list(df.columns)[k])
    
    df_with_avg = df[col_to_avg].fillna(df[col_to_avg].mean()) #Interpolate nan columns for all continuous-valued columns with average
    
    col_to_zero = list(df.columns)
    for k in range(len(list(df.columns))):
        if not list(df.columns)[k].startswith(('discrete', 'label')): #Remove all columns except label and discrete
            col_to_zero.remove(list(df.columns)[k])
    
    df_with_zero = df[col_to_zero].fillna(0) #Interpolate nan values for label and discrete columns with 0
    
    return pd.concat([df_with_avg, df_with_zero], axis = 1)

# %% [markdown]
# # Load and scale data

# %%
##load and scale data
#returns scaled data (X) and labels (Y)
#file_name: string, file with data to be used
#label: string, activity to do
def start_data(file_name, label):
    #read csv into dataframe
    data = pd.read_csv(file_name)
    
    #seperate only acceleration data
    X = data.iloc[:,1:27]
    y = data[[label]]

    #seperate only "on" labels
    X = X[y[label] == 1]
    y = y[y[label] == 1]
    
    #interpolate averages per column
    X = interpolation(X).values
    y = interpolation(y).values
    
    #scale the data
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X = sc.fit_transform(X)
    
    return X, y

# %% [markdown]
# # Generator Functions

# %%
#defines each generator layer
#input and output dimensions needed
def generator_block(input_dim, output_dim):
    return nn.Sequential(
        nn.Linear(input_dim, output_dim),
        nn.Dropout(0.1),
        nn.BatchNorm1d(output_dim),
        nn.ReLU(inplace = True)
    )

#returns n_samples of z_dim (number of dimensions of latent space) noise
def get_noise(n_samples, z_dim):
    #torch.manual_seed(0)
    return torch.randn(n_samples, z_dim).to(device)

#defines generator class
class Generator(nn.Module):
    def __init__(self, z_dim = 10, feature_dim = 26, hidden_dim = 128):
        super(Generator, self).__init__()
        self.gen = nn.Sequential(
            generator_block(z_dim, int(hidden_dim/2)),
            generator_block(int(hidden_dim/2), int(hidden_dim/4)),
            generator_block(int(hidden_dim/4), 30),
            generator_block(30, 28),
            nn.Linear(28, feature_dim)
        )
    def forward(self, noise):
        return self.gen(noise)

##calculates generator loss
#gen: generator
#disc: discriminator
#criterion: loss function
#batch_size: batch size
#z_dim: number of dimensions in the latent space
def get_gen_loss(gen, disc, criterion, batch_size, z_dim):
    latent_vectors = get_noise(batch_size, z_dim)
    fake_features = gen(latent_vectors)
    pred = disc(fake_features)
    gen_loss = criterion(pred, torch.ones_like(pred))
    return gen_loss

# %% [markdown]
# # Discriminator Functions

# %%
#defines each discriminator layer
def discriminator_block(input_dim, output_dim):
    return nn.Sequential(
        nn.Linear(input_dim, output_dim),
        nn.Dropout(0.1),
        nn.LeakyReLU(0.05)
    )

#defines discriminator class
class Discriminator(nn.Module):
    def __init__(self, feature_dim = 26, hidden_dim = 16):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            discriminator_block(feature_dim, hidden_dim),
            discriminator_block(hidden_dim, int(hidden_dim/2)),
            discriminator_block(int(hidden_dim/2), int(hidden_dim/4)),
            nn.Linear(int(hidden_dim/4), 1),
            nn.Sigmoid()                    
        )
    def forward(self, feature_vector):
        return self.disc(feature_vector)

##calculates discriminator loss
#gen: generator
#disc: discriminator
#real_features: real (not generated) data
#batch_size: batch size
#z_dim: number of dimensions of the latent space
def get_disc_loss(gen, disc, criterion, real_features, batch_size, z_dim):
    latent_vectors = get_noise(batch_size, z_dim)
    fake_features = gen(latent_vectors)
    pred_fake = disc(fake_features.detach())
    
    ground_truth = torch.zeros_like(pred_fake)
    loss_fake = criterion(pred_fake, ground_truth)
    
    pred_real = disc(real_features)
    ground_truth = torch.ones_like(pred_real)
    loss_real = criterion(pred_real, ground_truth)
    
    disc_loss = (loss_fake + loss_real) / 2
    return disc_loss

# %% [markdown]
# # Visualize Batches

# %%
##prints a plot of a generator batch
#gen: generator
#b_size: batch size
#epochs: current epoch (-1)
def visualize_gen_batch(gen, b_size, epochs = -1):
    #print(str(b_size))
    latent_vectors = get_noise(b_size, z_dim)
    #print(latent_vectors.shape)
    fake_features = gen(latent_vectors)
    #print(fake_features.shape)
    
    w_img = fake_features
    wmin = torch.min(w_img)
    wmax = torch.max(w_img)
    w_img = w_img.cpu()
    w_img = w_img.detach().numpy()
    c = plt.imshow(w_img, cmap ='Reds', vmin = wmin , vmax = wmax,
                        interpolation ='nearest', origin ='upper')
    plt.colorbar(c)
    plt.title('Generated Batch at Epoch ' + str(epochs), fontweight ="bold")
    plt.show()

##prints a plot of a batch of real data
#features: real data
def visualize_real_batch(features):
    w_img = features
    wmin = torch.min(w_img)
    wmax = torch.max(w_img)
    w_img = w_img.cpu()
    w_img = w_img.detach().numpy()
    c = plt.imshow(w_img, cmap ='Reds', vmin = wmin , vmax = wmax,
                        interpolation ='nearest', origin ='upper')
    plt.colorbar(c)
    plt.title('Real Batch of Data', fontweight ="bold")
    plt.show()

# %% [markdown]
# # Calculate Performance Statistics

# %%
##calculates performance statistics for each epoch of training
#gen: generator
#disc: discriminator
#b_size: batch size
#z_dim: number of dimensions of the latent space
##returns accuracy, precision, recall, fpR, and f1 score
def performance_stats(gen, disc, b_size, z_dim, batch = None):
    tp = 0 #true positive
    fp = 0 #false positive
    tn = 0 #true negative
    fn = 0 #false negative

    with torch.no_grad():
        if batch is None:
            latent_vectors = get_noise(b_size, z_dim)
            fake_features = gen(latent_vectors)
            y_hat = torch.round(disc(fake_features))
            y_label = [0] * b_size
            y_label = torch.Tensor(y_label).to(device)
        else:
            latent_vectors = get_noise(int(b_size/2), z_dim)
            fake_features = gen(latent_vectors)
            y_hat = torch.round(disc(fake_features))
            y_label = [0] * int(b_size/2)
            
            real_y_hat = torch.round(disc(batch[:int(b_size/2)]))
            for i in range(0, int(b_size/2)):
                y_label.append(1)
            y_hat = torch.cat((y_hat, real_y_hat), dim = 0).to(device)
            
            #print(y_hat)
            #print(y_label)
         
        
        for k in range(len(y_hat)):
            #True positive
            if y_label[k] == 1 and y_hat[k] == 1:
                tp += 1
            #False Negative
            elif y_label[k] == 1 and y_hat[k] == 0:
                fn += 1
            #True Negative
            elif y_label[k] == 0 and y_hat[k] == 0:
                tn += 1
            elif y_label[k] == 0 and y_hat[k] == 1:
                fp += 1
            else:
                print("Error")
                exit()
            
        class_acc = (tp + tn)/(tp + tn + fp + fn)
        
        if tp + fp == 0:
            precision = 0
        else:
            precision = tp / (tp + fp)
            
        if tp + fn == 0:
            recall = 0
        else:
            recall = tp / (tp + fn)
            
        if fp + tn == 0:
            fpR = 0
        else: 
            fpR = fp / (fp + tn)

        #print(f'Classification Accuracy: {class_acc:.2f}')
        #print(f'Precision: {precision:.2f}') #What percentage of a model's positive predictions were actually positive
        #print(f'Recall: {recall:.2f}') #What percent of the true positives were identified
        #print(f'F-1 Score: {2*(precision * recall / (precision + recall + 0.001)):.2f}')
        return class_acc, precision, recall, fpR, 2*(precision * recall / (precision + recall + 0.001))

# %% [markdown]
# # Create Density Curves

# %%
#create and plot density curves for mean, x, y, z acceleration
#reals: real data
#fakes: generated data
def density_curves(reals, fakes):
    plt.figure(figsize = (15, 15))
    subplot(2, 2, 1)
    sns.kdeplot(fakes.numpy()[:,0], color = 'r', shade = True, label = 'Fake Distribution')
    sns.kdeplot(reals[:,0], color = 'b', shade = True, label = 'Real Distribution')
    plt.xlabel('Mean Acceleration')
    plt.ylabel('Density')
    plt.legend()
    #plt.show()

    subplot(2, 2, 2)
    sns.kdeplot(fakes.numpy()[:,18], color = 'r', shade = True, label = 'Fake Distribution')
    sns.kdeplot(reals[:,18], color = 'b', shade = True, label = 'Real Distribution')
    plt.xlabel('Mean X-Acceleration')
    plt.ylabel('Density')
    plt.legend()
    #plt.show()

    subplot(2, 2, 3)
    sns.kdeplot(fakes.numpy()[:,19], color = 'r', shade = True, label = 'Fake Distribution')
    sns.kdeplot(reals[:,19], color = 'b', shade = True, label = 'Real Distribution')
    plt.xlabel('Mean Y-Acceleration')
    plt.ylabel('Density')
    plt.legend()
    #plt.show()

    subplot(2, 2, 4)
    sns.kdeplot(fakes.numpy()[:,20], color = 'r', shade = True, label = 'Fake Distribution')
    sns.kdeplot(reals[:,20], color = 'b', shade = True, label = 'Real Distribution')
    plt.xlabel('Mean Z-Acceleration')
    plt.ylabel('Density')
    plt.legend()
    plt.show()

# %% [markdown]
# # Create fake samples

# %%
def get_fake_samples(gen, batch_size, z_dim):
    """
    Generates fake acceleration features given a batch size, latent vector dimension, and trained generator.
    
    """
    latent_vectors = get_noise(batch_size, z_dim) ### Retrieves a 2D tensor of noise
    fake_features = gen(latent_vectors)
    
    return fake_features ### Returns a 2D tensor of fake features of size batch_size x z_dim

# %% [markdown]
# # Calculate Wassertein distance for each dimension

# %%
##calculate Waaserstein distances for each dimension
#gen: generator
#z_dim: number of dimensions of the latent space
#feature_dim: number ofd dimensions in the feature space
#sample: sample of data
def all_Wasserstein_dists(gen, z_dim, feature_dim, sample):
    wasser_dim = []
    latent_vectors = get_noise(len(sample), z_dim)
    fake_features = gen(latent_vectors)
    for k in range(feature_dim):
        wasser_dim.append(wasserstein_distance(fake_features[:, k].detach().numpy(), sample[:, k].detach().numpy()))
    return torch.tensor(wasser_dim)

# %%
###initalize parameters that depend on training loop parameters
#X: acceleration data
#y: labels associated with X data (fake or real)
#z_dim: number of dimensions to the latent space
#disc_lr: discriminator learning rate
#gen_lr: generator learning rate
#DISCRIMINATOR: 1 to indicate if discriminator is training
#batch_size: batch size
#disc: initialized discrimiantor

def initialize_params(X, y, z_dim, disc_lr, gen_lr, DISCRIMINATOR, batch_size, disc):
    #initialize generator
    gen = Generator(z_dim)
    #indicate that discriminator is training
    to_train = DISCRIMINATOR
    #create training features
    train_features = torch.tensor(X)
    #create training labels
    train_labels = torch.tensor(y)
    #concatenate to create training data
    train_data = torch.utils.data.TensorDataset(train_features, train_labels)
    #create data loader for training data
    train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, shuffle = True)
    #initialize generator and discriminator optimizers
    opt_disc = optim.Adam(disc.parameters(), lr = disc_lr)
    opt_gen = optim.Adam(gen.parameters(), lr = gen_lr)
    
    return gen, to_train, train_features, train_labels, train_data, train_loader, opt_disc, opt_gen

# %% [markdown]
# # Saving the Model

# %%
# Change path and name of the Generator and Discriminator accordingly
def save_model(model_name):
    torch.save(gen.state_dict(), "../saved_models/test_gan")
    torch.save(disc.state_dict(), "../saved_models/test_disc")

# %% [markdown]
# # Visualizing Generation Quality

# %%
#creates and prints a plot of the generated vs real data
#data: data used
#gen: generator
#z_dim: number of dimensions of the latent space
def visualize_gen(data, gen, z_dim):
    #Number of datum to visualize
    sample_size = len(data)
    reals = data[0:sample_size, :]
    fakes = get_fake_samples(gen, sample_size, z_dim).detach()
    density_curves(reals, fakes)

# %% [markdown]
# # Plot Metrics

# %%
#plot metrics based on data (csv)
def plot_metrics(data, vanilla = True):
    if vanilla:
        sns.set(style = 'whitegrid', context = 'talk', palette = 'rainbow')
    
        plt.figure(figsize = (15, 15))
        subplot(2, 2, 1)
        sns.scatterplot(x = 'Epoch', y = 'FPR', data = data).set(xlim = (0, None))
        sns.despine()
        
        subplot(2, 2, 2)
        sns.scatterplot(x = 'Epoch', y = 'Recall', data = data).set(xlim = (0, None))
        sns.despine()
        
        subplot(2, 2, 3)
        sns.regplot(x = 'Epoch', y = 'Median Wasserstein', data = data, line_kws = {'color': 'orange'}).set(xlim = (0, None))
        sns.despine()
        
        subplot(2, 2, 4)
        sns.regplot(x = 'Epoch', y = 'Mean Wasserstein', data = data, line_kws = {'color': 'orange'}).set(xlim = (0, None))
        sns.despine()
        plt.show()
    else:
        sns.set(style = 'whitegrid', context = 'talk', palette = 'rainbow')
        plt.figure(figsize = (15, 8))
        
        subplot(1, 2, 1)
        sns.regplot(x = 'Epoch', y = 'Median Wasserstein', data = data, line_kws = {'color': 'orange'}).set(xlim = (0, None))
        sns.despine()
        
        subplot(1, 2, 2)
        sns.regplot(x = 'Epoch', y = 'Mean Wasserstein', data = data, line_kws = {'color': 'orange'}).set(xlim = (0, None))
        sns.despine()
        
        plt.show()

# %% [markdown]
# # Training Loop

# %%
######Training loop to train GAN

#Parameters to specifiy: 
    #X: starting accelerometer data
    #y: starting labels for X data (fake or real)
    
#Set parameters (do not change)
    #criterion: loss function (BCE)
    #dig: number of significant digits for printing (5)
    #feature_dim: Number of dimensions of output from generator (26)
    #GENERATOR: set generator to zero for training
    #DISCRIMINATOR: set discriminator to one for training
    #train_string: starting machine to train (DISC)
    #disc: initalize discriminator
    #rel_epochs: Epochs passed since last switch (constant training) (0)
    #rows: initialization of array to save data of each epoch to CSV file ([])
    #heading: array of column headings for table (["Epoch", "Machine Training", "Discriminator Loss", 
                    #"Generator Loss", "FPR", "Recall", "Median Wasserstein", "Mean Wasserstein"])
    #table: intialize a table as a pretty table to save epoch data
    #switch_count: number of switches in dynamic training (0)
    
#Set parameters (can change):
    #z_dim: number of dimensions of latent vector (100)
    #gen_lr: generator learning rate (.001)
    #disc_lr: discriminator learning rate (.001) (shoud be equal to gen_lr)
    #batch_size: batch size (75)
    #print_batches: Show model performance per batch (False)
    #n_epochs: number of epochs to train (100)
    #constant_train_flag: (False)
        #Set to true to train based on constant # of epochs per machine 
        #Set to false to train dynamically based on machine performance
        
    #Constant training approach:
        #disc_epochs: Number of consecutive epochs to train discriminator before epoch threshold (5)
        #gen_epochs: Number of consecutive epochs to train generator before epoch threshold (2)
        #epoch_threshold: Epoch number to change training epoch ratio (50)
        #disc_epochs_change: New number of consecutive epochs to train discriminator after epoch threshold is exceeded (1)
        #gen_epochs_change: New number of consecutive epochs to train generator after epoch threshold is exceeded (50)
    
    #Dynamic training approach:                        
        #static_threshold: Epoch number to change from static ratio to dynamic (18)
        #static_disc_epochs: Number of consecutive epochs to train discriminator before epoch threshold (4)
        #static_gen_epochs: Number of consecutive epochs to train generator before epoch threshold (2)
        #pull_threshold: Accuracy threshold for switching machine training when the generator is no longer competitive (0.4)
        #push_threshold: Accuracy threshold for switching machine training when the discriminator is no longer competitive (0.6)
        #recall_threshold: threshold for recall to switch machine training when discriminator is training well
        #switch_flag: indicates if we should switch our training machine (False)
        
def training_loop(X, y, criterion = nn.BCELoss(), gan_id = "Mod Test Gan", dig = 5, feature_dim = 26, 
                  GENERATOR = 0, DISCRIMINATOR = 1, train_string = "DISC", disc = Discriminator(), z_dim = 100, 
                  gen_lr =  0.001, disc_lr = 0.001, batch_size = 100, constant_train_flag = False, disc_epochs = 5,
                  gen_epochs = 2, epoch_threshold = 50, disc_epochs_change = 1, gen_epochs_change = 50, rel_epochs = 0,
                 static_threshold = 18, static_disc_epochs = 4, static_gen_epochs = 2, pull_threshold = 0.4,
                 push_threshold = 0.6, recall_threshold = 0.85, print_batches = False, n_epochs = 1000, rows = [],
                 heading = ["Epoch", "Machine Training", "Discriminator Loss", "Generator Loss", "FPR", "Recall", "Median Wasserstein", "Mean Wasserstein"],
                 table = PrettyTable(), switch_flag = False, switch_count = 0, last_real_features = []):
    
    #returns generator, sets discriminator training, creates training tensor, loads data, and initializes optimizers
    gen, to_train, train_features, train_labels, train_data, train_loader, opt_disc, opt_gen = initialize_params(X, y, z_dim, disc_lr, gen_lr, DISCRIMINATOR, batch_size, disc)

    #set pretty table field names
    table.field_names = heading
    
    visualize_gen(X, gen, z_dim)

    for epoch in range(n_epochs):  
        if constant_train_flag:
            if to_train == DISCRIMINATOR and rel_epochs >= disc_epochs:
                rel_epochs = 0
                to_train = GENERATOR
                train_string = "GEN"

            elif to_train == GENERATOR and rel_epochs >= gen_epochs:
                rel_epochs = 0
                to_train = DISCRIMINATOR
                train_string = "DISC"

            # Change epoch ratio after intial 'leveling out'
            if epoch == epoch_threshold:
                rel_epochs = 0
                to_train = GENERATOR
                train_string = "GENERATOR"

                old_ratio = gen_epochs / disc_epochs
                gen_epochs = gen_epochs_change
                disc_epochs = disc_epochs_change
                new_ratio = gen_epochs / disc_epochs
                print(f'\n\nTraining ratio of G/D switched from {old_ratio:.{dig}f} to {new_ratio:.{dig}f}\n\n')
        else:
            if epoch < static_threshold:
                if to_train == DISCRIMINATOR and rel_epochs >= static_disc_epochs:
                    rel_epochs = 0
                    to_train = GENERATOR
                    train_string = "GEN"

                elif to_train == GENERATOR and rel_epochs >= static_gen_epochs:
                    rel_epochs = 0
                    to_train = DISCRIMINATOR
                    train_string = "DISC"

            else:
                #to_train = DISCRIMINATOR
                #train_string = "DISC"
                if not switch_flag:
                    print("\nSwitching to Dynamic Training\n")
                    switch_flag = True
                if to_train == DISCRIMINATOR and fpR <= pull_threshold and R >= recall_threshold:
                    to_train = GENERATOR
                    train_string = "GEN"
                    print("\nPull Generator\n")
                    switch_count += 1
                if to_train == GENERATOR and fpR >= push_threshold:
                    to_train = DISCRIMINATOR
                    train_string = "DISC"
                    print("\nPush Generator\n")
                    switch_count += 1
        print(f'Epoch [{epoch + 1}/{n_epochs}] Training: {train_string} ', end ='')
        for batch_idx, (real_features, _) in enumerate(train_loader):
            #batch_size = len(real_features)

            if print_batches:
                    print(f'\n\tBatch [{batch_idx + 1} / {len(train_loader)}] |', end ='')

            if to_train == DISCRIMINATOR:
                ### Training Discriminator
                #visualize_real_batch(real_features.float())
                opt_disc.zero_grad()
                disc_loss = get_disc_loss(gen, disc, criterion, real_features.float(), batch_size, z_dim)
                disc_loss.backward(retain_graph = True)
                opt_disc.step()
                acc, P, R, fpR, F1 = performance_stats(gen, disc, batch_size, z_dim, batch = real_features.float())
                w_dist = all_Wasserstein_dists(gen, z_dim, feature_dim, real_features.float())
                median_w_dist = torch.median(w_dist)
                mean_w_dist = torch.mean(w_dist)
                if print_batches:
                    print(f'Loss D: {disc_loss.item():.digf}, Loss G: {get_gen_loss(gen, disc, criterion, batch_size, z_dim):.{dig}f} | Accuracy: {acc:.{dig}f} | fpR: {fpR:.{dig}f} P: {P:.{dig}f} | R: {R:.{dig}f} | F1: {F1:.{dig}f} | Median Wasserstein: {median_w_dist:.{dig}f} | Mean Wasserstein: {mean_w_dist:.{dig}f}')
            else:
                ### Training Generator
                opt_gen.zero_grad()
                gen_loss = get_gen_loss(gen, disc, criterion, batch_size, z_dim)
                gen_loss.backward()
                opt_gen.step()
                acc, P, R, fpR, F1 = performance_stats(gen, disc, batch_size, z_dim, batch = real_features.float())
                w_dist = all_Wasserstein_dists(gen, z_dim, feature_dim, real_features.float())
                median_w_dist = torch.median(w_dist)
                mean_w_dist = torch.mean(w_dist)
                if print_batches:
                    print(f'Loss D: {disc_loss.item():.digf}, Loss G: {get_gen_loss(gen, disc, criterion, batch_size, z_dim):.{dig}f} | Accuracy: {acc:.{dig}f} | fpR: {fpR:.{dig}f} P: {P:.{dig}f} | R: {R:.{dig}f} | F1: {F1:.{dig}f} | Median Wasserstein: {median_w_dist:.{dig}f} | Mean Wasserstein: {mean_w_dist:.{dig}f}')

        if not print_batches:
            if to_train == DISCRIMINATOR:
                ### Currently doesn't print Median/Mean Wasserstein --> Change if needed
                print(f'| Loss D: {disc_loss.item():.{dig}f}, Loss G: {get_gen_loss(gen, disc, criterion, batch_size, z_dim):.{dig}f} | Accuracy: {acc:.{dig}f} | fpR: {fpR:.{dig}f} | P: {P:.{dig}f} | R: {R:.{dig}f} | F1: {F1:.{dig}f}')
                row_to_add = [f"{epoch + 1}", "Discriminator", f"{disc_loss.item():.{dig}f}", f"{get_gen_loss(gen, disc, criterion, batch_size, z_dim):.{dig}f}", f"{fpR:.{dig}f}", f"{R:.{dig}f}", f"{median_w_dist:.{dig}f}", f"{mean_w_dist:.{dig}f}"]
                table.add_row(row_to_add)
                rows.append(row_to_add)
            else:
                print(f'| Loss D: {get_disc_loss(gen, disc, criterion, real_features.float(), batch_size, z_dim):.{dig}f}, Loss G: {gen_loss.item():.{dig}f} | Accuracy: {acc:.{dig}f} | fpR: {fpR:.{dig}f} | P: {P:.{dig}f} | R: {R:.{dig}f} | F1: {F1:.{dig}f}')
                row_to_add = [f"{epoch + 1}", "Discriminator", f"{disc_loss.item():.{dig}f}", f"{get_gen_loss(gen, disc, criterion, batch_size, z_dim):.{dig}f}", f"{fpR:.{dig}f}", f"{R:.{dig}f}", f"{median_w_dist:.{dig}f}", f"{mean_w_dist:.{dig}f}"]
                table.add_row(row_to_add)
                rows.append(row_to_add)
        rel_epochs += 1
    print("\n\nTraining Session Finished")
    print(f"Encountered {switch_count} non-trivial training swaps")

    f = open("../model_outputs/" + gan_id + ".txt", "w")
    f.write(table.get_string())
    f.close()
    print("Model Results Sucessfully Saved to \"../model_outputs/" + gan_id + ".txt\"")

    with open("../model_outputs/" + gan_id + ".csv", "w") as csvfile: 
        # creating a csv writer object 
        csvwriter = csv.writer(csvfile) 
        # writing the fields 
        csvwriter.writerow(heading)
        # writing the data rows 
        csvwriter.writerows(rows)
    print("Model Results Sucessfully Saved to \"../model_outputs/" + gan_id + ".csv\"")
    model_output = pd.read_csv('../model_outputs/Mod Test Gan.csv')
    visualize_gen(X, gen, z_dim)
    
    return model_output

# %% [markdown]
# # Running training

# %%
X, y = start_data("098A72A5-E3E5-4F54-A152-BBDA0DF7B694.features_labels.csv.gz", "label:SITTING") 
model_output = training_loop(X,y, batch_size = 250, gen_lr=.0001, disc_lr = .0001, n_epochs = 2000)
plot_metrics(model_output, True)
# Out:
# Epoch [1/2000] Training: DISC | Loss D: 0.70223, Loss G: 0.80176 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [2/2000] Training: DISC | Loss D: 0.70202, Loss G: 0.79893 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [3/2000] Training: DISC | Loss D: 0.70557, Loss G: 0.79790 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [4/2000] Training: DISC | Loss D: 0.70411, Loss G: 0.79662 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [5/2000] Training: GEN | Loss D: 0.70219, Loss G: 0.79475 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [6/2000] Training: GEN | Loss D: 0.70265, Loss G: 0.79429 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [7/2000] Training: DISC | Loss D: 0.70200, Loss G: 0.79402 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [8/2000] Training: DISC | Loss D: 0.69936, Loss G: 0.79171 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [9/2000] Training: DISC | Loss D: 0.70017, Loss G: 0.78903 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [10/2000] Training: DISC | Loss D: 0.70086, Loss G: 0.78984 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [11/2000] Training: GEN | Loss D: 0.70035, Loss G: 0.79127 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [12/2000] Training: GEN | Loss D: 0.70085, Loss G: 0.78880 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [13/2000] Training: DISC | Loss D: 0.69727, Loss G: 0.78487 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [14/2000] Training: DISC | Loss D: 0.70015, Loss G: 0.78872 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [15/2000] Training: DISC | Loss D: 0.69649, Loss G: 0.78525 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [16/2000] Training: DISC | Loss D: 0.69732, Loss G: 0.78407 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [17/2000] Training: GEN | Loss D: 0.69705, Loss G: 0.78335 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [18/2000] Training: GEN | Loss D: 0.69841, Loss G: 0.78281 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
#
# Switching to Dynamic Training
#
# Epoch [19/2000] Training: GEN | Loss D: 0.69676, Loss G: 0.78039 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [20/2000] Training: GEN | Loss D: 0.69790, Loss G: 0.78065 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [21/2000] Training: GEN | Loss D: 0.69609, Loss G: 0.77692 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [22/2000] Training: GEN | Loss D: 0.69798, Loss G: 0.78213 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [23/2000] Training: GEN | Loss D: 0.69652, Loss G: 0.78044 | Accuracy: 0.50400 | fpR: 0.00000 | P: 1.00000 | R: 0.00800 | F1: 0.01586
# Epoch [24/2000] Training: GEN | Loss D: 0.70099, Loss G: 0.77960 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [25/2000] Training: GEN | Loss D: 0.70026, Loss G: 0.77758 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [26/2000] Training: GEN | Loss D: 0.70304, Loss G: 0.77348 | Accuracy: 0.50400 | fpR: 0.00000 | P: 1.00000 | R: 0.00800 | F1: 0.01586
# Epoch [27/2000] Training: GEN | Loss D: 0.69902, Loss G: 0.77507 | Accuracy: 0.50400 | fpR: 0.00000 | P: 1.00000 | R: 0.00800 | F1: 0.01586
# Epoch [28/2000] Training: GEN | Loss D: 0.70168, Loss G: 0.77598 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [29/2000] Training: GEN | Loss D: 0.70017, Loss G: 0.77387 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [30/2000] Training: GEN | Loss D: 0.70006, Loss G: 0.77510 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [31/2000] Training: GEN | Loss D: 0.70108, Loss G: 0.77196 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [32/2000] Training: GEN | Loss D: 0.70252, Loss G: 0.77228 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [33/2000] Training: GEN | Loss D: 0.70293, Loss G: 0.77241 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [34/2000] Training: GEN | Loss D: 0.70622, Loss G: 0.77241 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [35/2000] Training: GEN | Loss D: 0.70408, Loss G: 0.76993 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [36/2000] Training: GEN | Loss D: 0.70218, Loss G: 0.77180 | Accuracy: 0.49600 | fpR: 0.00800 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [37/2000] Training: GEN | Loss D: 0.70439, Loss G: 0.77166 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [38/2000] Training: GEN | Loss D: 0.70350, Loss G: 0.77027 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [39/2000] Training: GEN | Loss D: 0.70376, Loss G: 0.76631 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [40/2000] Training: GEN | Loss D: 0.70475, Loss G: 0.76715 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [41/2000] Training: GEN | Loss D: 0.70631, Loss G: 0.76297 | Accuracy: 0.49600 | fpR: 0.00800 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [42/2000] Training: GEN | Loss D: 0.70427, Loss G: 0.76516 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [43/2000] Training: GEN | Loss D: 0.70657, Loss G: 0.76471 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [44/2000] Training: GEN | Loss D: 0.70842, Loss G: 0.76131 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [45/2000] Training: GEN | Loss D: 0.70554, Loss G: 0.76230 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [46/2000] Training: GEN | Loss D: 0.70748, Loss G: 0.76290 | Accuracy: 0.49600 | fpR: 0.00800 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [47/2000] Training: GEN | Loss D: 0.70902, Loss G: 0.76019 | Accuracy: 0.48800 | fpR: 0.02400 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [48/2000] Training: GEN | Loss D: 0.70680, Loss G: 0.75831 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [49/2000] Training: GEN | Loss D: 0.70828, Loss G: 0.75739 | Accuracy: 0.49600 | fpR: 0.00800 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [50/2000] Training: GEN | Loss D: 0.70964, Loss G: 0.75496 | Accuracy: 0.48800 | fpR: 0.02400 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [51/2000] Training: GEN | Loss D: 0.71093, Loss G: 0.75142 | Accuracy: 0.49200 | fpR: 0.01600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [52/2000] Training: GEN | Loss D: 0.71035, Loss G: 0.75299 | Accuracy: 0.49600 | fpR: 0.00800 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [53/2000] Training: GEN | Loss D: 0.70642, Loss G: 0.75778 | Accuracy: 0.48400 | fpR: 0.03200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [54/2000] Training: GEN | Loss D: 0.71113, Loss G: 0.75190 | Accuracy: 0.48800 | fpR: 0.02400 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [55/2000] Training: GEN | Loss D: 0.71087, Loss G: 0.74835 | Accuracy: 0.48000 | fpR: 0.04800 | P: 0.14286 | R: 0.00800 | F1: 0.01505
# Epoch [56/2000] Training: GEN | Loss D: 0.71094, Loss G: 0.74677 | Accuracy: 0.48400 | fpR: 0.03200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [57/2000] Training: GEN | Loss D: 0.71078, Loss G: 0.74871 | Accuracy: 0.47200 | fpR: 0.05600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [58/2000] Training: GEN | Loss D: 0.71384, Loss G: 0.74629 | Accuracy: 0.47200 | fpR: 0.05600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [59/2000] Training: GEN | Loss D: 0.71521, Loss G: 0.74619 | Accuracy: 0.47200 | fpR: 0.05600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [60/2000] Training: GEN | Loss D: 0.71475, Loss G: 0.74214 | Accuracy: 0.48000 | fpR: 0.04000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [61/2000] Training: GEN | Loss D: 0.71718, Loss G: 0.74466 | Accuracy: 0.47200 | fpR: 0.05600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [62/2000] Training: GEN | Loss D: 0.71616, Loss G: 0.74182 | Accuracy: 0.45200 | fpR: 0.09600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [63/2000] Training: GEN | Loss D: 0.71303, Loss G: 0.74059 | Accuracy: 0.48000 | fpR: 0.04000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [64/2000] Training: GEN | Loss D: 0.71721, Loss G: 0.73527 | Accuracy: 0.45600 | fpR: 0.08800 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [65/2000] Training: GEN | Loss D: 0.71947, Loss G: 0.73508 | Accuracy: 0.43200 | fpR: 0.13600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [66/2000] Training: GEN | Loss D: 0.71866, Loss G: 0.73913 | Accuracy: 0.44400 | fpR: 0.11200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [67/2000] Training: GEN | Loss D: 0.71871, Loss G: 0.73509 | Accuracy: 0.41200 | fpR: 0.17600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [68/2000] Training: GEN | Loss D: 0.71670, Loss G: 0.72931 | Accuracy: 0.44800 | fpR: 0.10400 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [69/2000] Training: GEN | Loss D: 0.71812, Loss G: 0.73005 | Accuracy: 0.44400 | fpR: 0.11200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [70/2000] Training: GEN | Loss D: 0.72140, Loss G: 0.73524 | Accuracy: 0.42400 | fpR: 0.15200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [71/2000] Training: GEN | Loss D: 0.72222, Loss G: 0.73105 | Accuracy: 0.40800 | fpR: 0.18400 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [72/2000] Training: GEN | Loss D: 0.72096, Loss G: 0.72733 | Accuracy: 0.42400 | fpR: 0.15200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [73/2000] Training: GEN | Loss D: 0.72124, Loss G: 0.72440 | Accuracy: 0.40000 | fpR: 0.20000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [74/2000] Training: GEN | Loss D: 0.72384, Loss G: 0.72786 | Accuracy: 0.38000 | fpR: 0.24000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [75/2000] Training: GEN | Loss D: 0.72393, Loss G: 0.72572 | Accuracy: 0.38000 | fpR: 0.24000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [76/2000] Training: GEN | Loss D: 0.72582, Loss G: 0.72076 | Accuracy: 0.36800 | fpR: 0.26400 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [77/2000] Training: GEN | Loss D: 0.72226, Loss G: 0.72389 | Accuracy: 0.33600 | fpR: 0.32800 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [78/2000] Training: GEN | Loss D: 0.72658, Loss G: 0.72331 | Accuracy: 0.32000 | fpR: 0.36000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [79/2000] Training: GEN | Loss D: 0.72821, Loss G: 0.72054 | Accuracy: 0.33200 | fpR: 0.33600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [80/2000] Training: GEN | Loss D: 0.72926, Loss G: 0.71832 | Accuracy: 0.33600 | fpR: 0.32800 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [81/2000] Training: GEN | Loss D: 0.72718, Loss G: 0.72139 | Accuracy: 0.30000 | fpR: 0.40000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [82/2000] Training: GEN | Loss D: 0.72927, Loss G: 0.71432 | Accuracy: 0.35200 | fpR: 0.29600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [83/2000] Training: GEN | Loss D: 0.72959, Loss G: 0.70859 | Accuracy: 0.30000 | fpR: 0.40000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [84/2000] Training: GEN | Loss D: 0.72821, Loss G: 0.71609 | Accuracy: 0.28400 | fpR: 0.43200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [85/2000] Training: GEN | Loss D: 0.73154, Loss G: 0.71423 | Accuracy: 0.30800 | fpR: 0.38400 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [86/2000] Training: GEN | Loss D: 0.73138, Loss G: 0.71250 | Accuracy: 0.29200 | fpR: 0.41600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [87/2000] Training: GEN | Loss D: 0.73372, Loss G: 0.70708 | Accuracy: 0.26400 | fpR: 0.47200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [88/2000] Training: GEN | Loss D: 0.73215, Loss G: 0.70709 | Accuracy: 0.24400 | fpR: 0.52000 | P: 0.01515 | R: 0.00800 | F1: 0.01004
# Epoch [89/2000] Training: GEN | Loss D: 0.73391, Loss G: 0.70379 | Accuracy: 0.22400 | fpR: 0.56000 | P: 0.01408 | R: 0.00800 | F1: 0.00976
# Epoch [90/2000] Training: GEN | Loss D: 0.73288, Loss G: 0.70138 | Accuracy: 0.22000 | fpR: 0.56000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [91/2000] Training: GEN | Loss D: 0.73499, Loss G: 0.70853 | Accuracy: 0.24000 | fpR: 0.52800 | P: 0.01493 | R: 0.00800 | F1: 0.00998
# Epoch [92/2000] Training: GEN | Loss D: 0.73448, Loss G: 0.70131 | Accuracy: 0.25200 | fpR: 0.49600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [93/2000] Training: GEN | Loss D: 0.73541, Loss G: 0.70383 | Accuracy: 0.21600 | fpR: 0.57600 | P: 0.01370 | R: 0.00800 | F1: 0.00966
# Epoch [94/2000] Training: GEN | Loss D: 0.74011, Loss G: 0.70548 | Accuracy: 0.22400 | fpR: 0.55200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [95/2000] Training: GEN | Loss D: 0.73594, Loss G: 0.69750 | Accuracy: 0.22400 | fpR: 0.55200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [96/2000] Training: GEN | Loss D: 0.73391, Loss G: 0.69882 | Accuracy: 0.19600 | fpR: 0.61600 | P: 0.01282 | R: 0.00800 | F1: 0.00940
#
# Push Generator
#
# Epoch [97/2000] Training: DISC | Loss D: 0.73699, Loss G: 0.70021 | Accuracy: 0.20000 | fpR: 0.60000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [98/2000] Training: DISC | Loss D: 0.73030, Loss G: 0.70619 | Accuracy: 0.30400 | fpR: 0.39200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [99/2000] Training: DISC | Loss D: 0.72864, Loss G: 0.70981 | Accuracy: 0.24800 | fpR: 0.50400 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [100/2000] Training: DISC | Loss D: 0.72618, Loss G: 0.71575 | Accuracy: 0.29600 | fpR: 0.41600 | P: 0.01887 | R: 0.00800 | F1: 0.01083
# Epoch [101/2000] Training: DISC | Loss D: 0.72642, Loss G: 0.72355 | Accuracy: 0.35200 | fpR: 0.30400 | P: 0.02564 | R: 0.00800 | F1: 0.01184
# Epoch [102/2000] Training: DISC | Loss D: 0.72103, Loss G: 0.72871 | Accuracy: 0.37200 | fpR: 0.25600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [103/2000] Training: DISC | Loss D: 0.71815, Loss G: 0.72804 | Accuracy: 0.43200 | fpR: 0.13600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [104/2000] Training: DISC | Loss D: 0.71355, Loss G: 0.73256 | Accuracy: 0.44000 | fpR: 0.12000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [105/2000] Training: DISC | Loss D: 0.71416, Loss G: 0.74380 | Accuracy: 0.47200 | fpR: 0.05600 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [106/2000] Training: DISC | Loss D: 0.71215, Loss G: 0.75014 | Accuracy: 0.48400 | fpR: 0.04000 | P: 0.16667 | R: 0.00800 | F1: 0.01518
# Epoch [107/2000] Training: DISC | Loss D: 0.70579, Loss G: 0.75854 | Accuracy: 0.48400 | fpR: 0.03200 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [108/2000] Training: DISC | Loss D: 0.69870, Loss G: 0.76914 | Accuracy: 0.50400 | fpR: 0.00000 | P: 1.00000 | R: 0.00800 | F1: 0.01586
# Epoch [109/2000] Training: DISC | Loss D: 0.69708, Loss G: 0.77796 | Accuracy: 0.49600 | fpR: 0.00800 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [110/2000] Training: DISC | Loss D: 0.69075, Loss G: 0.78845 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [111/2000] Training: DISC | Loss D: 0.68805, Loss G: 0.79491 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [112/2000] Training: DISC | Loss D: 0.68323, Loss G: 0.80697 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [113/2000] Training: DISC | Loss D: 0.67761, Loss G: 0.81980 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [114/2000] Training: DISC | Loss D: 0.67324, Loss G: 0.82620 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [115/2000] Training: DISC | Loss D: 0.67064, Loss G: 0.83321 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [116/2000] Training: DISC | Loss D: 0.66984, Loss G: 0.84203 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [117/2000] Training: DISC | Loss D: 0.66622, Loss G: 0.84579 | Accuracy: 0.50800 | fpR: 0.00000 | P: 1.00000 | R: 0.01600 | F1: 0.03147
# Epoch [118/2000] Training: DISC | Loss D: 0.66188, Loss G: 0.85519 | Accuracy: 0.50000 | fpR: 0.00000 | P: 0.00000 | R: 0.00000 | F1: 0.00000
# Epoch [119/2000] Training: DISC | Loss D: 0.65778, Loss G: 0.85460 | Accuracy: 0.50400 | fpR: 0.00000 | P: 1.00000 | R: 0.00800 | F1: 0.01586
# Epoch [120/2000] Training: DISC | Loss D: 0.65706, Loss G: 0.85904 | Accuracy: 0.50000 | fpR: 0.00800 | P: 0.50000 | R: 0.00800 | F1: 0.01572
# Epoch [121/2000] Training: DISC | Loss D: 0.65334, Loss G: 0.86701 | Accuracy: 0.50400 | fpR: 0.00000 | P: 1.00000 | R: 0.00800 | F1: 0.01586
# Epoch [122/2000] Training: DISC | Loss D: 0.65014, Loss G: 0.86911 | Accuracy: 0.50400 | fpR: 0.00000 | P: 1.00000 | R: 0.00800 | F1: 0.01586
# Epoch [123/2000] Training: DISC | Loss D: 0.64701, Loss G: 0.88067 | Accuracy: 0.51600 | fpR: 0.00000 | P: 1.00000 | R: 0.03200 | F1: 0.06196
# Epoch [124/2000] Training: DISC | Loss D: 0.64567, Loss G: 0.88570 | Accuracy: 0.50400 | fpR: 0.00000 | P: 1.00000 | R: 0.00800 | F1: 0.01586
# Epoch [125/2000] Training: DISC | Loss D: 0.64056, Loss G: 0.89151 | Accuracy: 0.50800 | fpR: 0.00000 | P: 1.00000 | R: 0.01600 | F1: 0.03147
# Epoch [126/2000] Training: DISC | Loss D: 0.63689, Loss G: 0.90005 | Accuracy: 0.52000 | fpR: 0.00000 | P: 1.00000 | R: 0.04000 | F1: 0.07685
# Epoch [127/2000] Training: DISC | Loss D: 0.63385, Loss G: 0.90281 | Accuracy: 0.53600 | fpR: 0.00000 | P: 1.00000 | R: 0.07200 | F1: 0.13420
# Epoch [128/2000] Training: DISC | Loss D: 0.63211, Loss G: 0.90929 | Accuracy: 0.51600 | fpR: 0.00000 | P: 1.00000 | R: 0.03200 | F1: 0.06196
# Epoch [129/2000] Training: DISC | Loss D: 0.62939, Loss G: 0.91476 | Accuracy: 0.55200 | fpR: 0.00000 | P: 1.00000 | R: 0.10400 | F1: 0.18824
# Epoch [130/2000] Training: DISC | Loss D: 0.63013, Loss G: 0.92507 | Accuracy: 0.52400 | fpR: 0.00000 | P: 1.00000 | R: 0.04800 | F1: 0.09152
# Epoch [131/2000] Training: DISC | Loss D: 0.62408, Loss G: 0.93483 | Accuracy: 0.55200 | fpR: 0.00000 | P: 1.00000 | R: 0.10400 | F1: 0.18824
# Epoch [132/2000] Training: DISC | Loss D: 0.61683, Loss G: 0.93875 | Accuracy: 0.54800 | fpR: 0.00000 | P: 1.00000 | R: 0.09600 | F1: 0.17502
# Epoch [133/2000] Training: DISC | Loss D: 0.61745, Loss G: 0.93610 | Accuracy: 0.56800 | fpR: 0.00000 | P: 1.00000 | R: 0.13600 | F1: 0.23923
# Epoch [134/2000] Training: DISC | Loss D: 0.61343, Loss G: 0.94912 | Accuracy: 0.56000 | fpR: 0.00000 | P: 1.00000 | R: 0.12000 | F1: 0.21409
# Epoch [135/2000] Training: DISC | Loss D: 0.61242, Loss G: 0.95249 | Accuracy: 0.64400 | fpR: 0.00000 | P: 1.00000 | R: 0.28800 | F1: 0.44686
# Epoch [136/2000] Training: DISC | Loss D: 0.61182, Loss G: 0.96646 | Accuracy: 0.62400 | fpR: 0.00000 | P: 1.00000 | R: 0.24800 | F1: 0.39712
# Epoch [137/2000] Training: DISC | Loss D: 0.60128, Loss G: 0.96468 | Accuracy: 0.63200 | fpR: 0.00000 | P: 1.00000 | R: 0.26400 | F1: 0.41739
# Epoch [138/2000] Training: DISC | Loss D: 0.60174, Loss G: 0.98038 | Accuracy: 0.63600 | fpR: 0.00000 | P: 1.00000 | R: 0.27200 | F1: 0.42734
# Epoch [139/2000] Training: DISC | Loss D: 0.59913, Loss G: 0.99254 | Accuracy: 0.69600 | fpR: 0.00000 | P: 1.00000 | R: 0.39200 | F1: 0.56281
# Epoch [140/2000] Training: DISC | Loss D: 0.59067, Loss G: 0.99801 | Accuracy: 0.70000 | fpR: 0.00000 | P: 1.00000 | R: 0.40000 | F1: 0.57102
# Epoch [141/2000] Training: DISC | Loss D: 0.59016, Loss G: 1.00648 | Accuracy: 0.66000 | fpR: 0.01600 | P: 0.95455 | R: 0.33600 | F1: 0.49666
# Epoch [142/2000] Training: DISC | Loss D: 0.58513, Loss G: 1.02837 | Accuracy: 0.68400 | fpR: 0.00000 | P: 1.00000 | R: 0.36800 | F1: 0.53762
# Epoch [143/2000] Training: DISC | Loss D: 0.58478, Loss G: 1.03132 | Accuracy: 0.72800 | fpR: 0.00000 | P: 1.00000 | R: 0.45600 | F1: 0.62594
# Epoch [144/2000] Training: DISC | Loss D: 0.57999, Loss G: 1.03723 | Accuracy: 0.74400 | fpR: 0.00000 | P: 1.00000 | R: 0.48800 | F1: 0.65547
# Epoch [145/2000] Training: DISC | Loss D: 0.57648, Loss G: 1.03446 | Accuracy: 0.76400 | fpR: 0.00000 | P: 1.00000 | R: 0.52800 | F1: 0.69065
# Epoch [146/2000] Training: DISC | Loss D: 0.56674, Loss G: 1.05849 | Accuracy: 0.77200 | fpR: 0.00000 | P: 1.00000 | R: 0.54400 | F1: 0.70421
# Epoch [147/2000] Training: DISC | Loss D: 0.56596, Loss G: 1.06853 | Accuracy: 0.77200 | fpR: 0.00000 | P: 1.00000 | R: 0.54400 | F1: 0.70421
# Epoch [148/2000] Training: DISC | Loss D: 0.55681, Loss G: 1.06707 | Accuracy: 0.76800 | fpR: 0.00000 | P: 1.00000 | R: 0.53600 | F1: 0.69746
# Epoch [149/2000] Training: DISC | Loss D: 0.56203, Loss G: 1.08301 | Accuracy: 0.78000 | fpR: 0.00800 | P: 0.98611 | R: 0.56800 | F1: 0.72035
# Epoch [150/2000] Training: DISC | Loss D: 0.55142, Loss G: 1.09470 | Accuracy: 0.78400 | fpR: 0.00800 | P: 0.98630 | R: 0.57600 | F1: 0.72681
# Epoch [151/2000] Training: DISC | Loss D: 0.54912, Loss G: 1.12511 | Accuracy: 0.81200 | fpR: 0.00000 | P: 1.00000 | R: 0.62400 | F1: 0.76800
# Epoch [152/2000] Training: DISC | Loss D: 0.54254, Loss G: 1.12137 | Accuracy: 0.81200 | fpR: 0.00000 | P: 1.00000 | R: 0.62400 | F1: 0.76800
# Epoch [153/2000] Training: DISC | Loss D: 0.53569, Loss G: 1.14997 | Accuracy: 0.82800 | fpR: 0.00000 | P: 1.00000 | R: 0.65600 | F1: 0.79179
# Epoch [154/2000] Training: DISC | Loss D: 0.54106, Loss G: 1.15174 | Accuracy: 0.82400 | fpR: 0.00800 | P: 0.98795 | R: 0.65600 | F1: 0.78798
# Epoch [155/2000] Training: DISC | Loss D: 0.53224, Loss G: 1.17857 | Accuracy: 0.84400 | fpR: 0.00000 | P: 1.00000 | R: 0.68800 | F1: 0.81468
# Epoch [156/2000] Training: DISC | Loss D: 0.52580, Loss G: 1.20485 | Accuracy: 0.86400 | fpR: 0.00000 | P: 1.00000 | R: 0.72800 | F1: 0.84211
# Epoch [157/2000] Training: DISC | Loss D: 0.51839, Loss G: 1.20894 | Accuracy: 0.87200 | fpR: 0.00000 | P: 1.00000 | R: 0.74400 | F1: 0.85272
# Epoch [158/2000] Training: DISC | Loss D: 0.51319, Loss G: 1.24766 | Accuracy: 0.85600 | fpR: 0.00800 | P: 0.98901 | R: 0.72000 | F1: 0.83285
# Epoch [159/2000] Training: DISC | Loss D: 0.51255, Loss G: 1.22918 | Accuracy: 0.86000 | fpR: 0.00000 | P: 1.00000 | R: 0.72000 | F1: 0.83672
# Epoch [160/2000] Training: DISC | Loss D: 0.50451, Loss G: 1.26673 | Accuracy: 0.86400 | fpR: 0.00800 | P: 0.98925 | R: 0.73600 | F1: 0.84355
# Epoch [161/2000] Training: DISC | Loss D: 0.50436, Loss G: 1.27864 | Accuracy: 0.86800 | fpR: 0.00000 | P: 1.00000 | R: 0.73600 | F1: 0.84744
# Epoch [162/2000] Training: DISC | Loss D: 0.49443, Loss G: 1.29593 | Accuracy: 0.86800 | fpR: 0.00000 | P: 1.00000 | R: 0.73600 | F1: 0.84744
# Epoch [163/2000] Training: DISC | Loss D: 0.48756, Loss G: 1.27625 | Accuracy: 0.90800 | fpR: 0.00000 | P: 1.00000 | R: 0.81600 | F1: 0.89818
# Epoch [164/2000] Training: DISC | Loss D: 0.49350, Loss G: 1.37146 | Accuracy: 0.86400 | fpR: 0.00000 | P: 1.00000 | R: 0.72800 | F1: 0.84211
# Epoch [165/2000] Training: DISC | Loss D: 0.48639, Loss G: 1.35629 | Accuracy: 0.91600 | fpR: 0.00000 | P: 1.00000 | R: 0.83200 | F1: 0.90780
# Epoch [166/2000] Training: DISC | Loss D: 0.47563, Loss G: 1.39454 | Accuracy: 0.91600 | fpR: 0.00800 | P: 0.99057 | R: 0.84000 | F1: 0.90859
# Epoch [167/2000] Training: DISC | Loss D: 0.46772, Loss G: 1.39614 | Accuracy: 0.88000 | fpR: 0.00000 | P: 1.00000 | R: 0.76000 | F1: 0.86315
# Epoch [168/2000] Training: DISC | Loss D: 0.46450, Loss G: 1.43854 | Accuracy: 0.86800 | fpR: 0.01600 | P: 0.97917 | R: 0.75200 | F1: 0.85019
# Epoch [169/2000] Training: DISC | Loss D: 0.46666, Loss G: 1.46429 | Accuracy: 0.86400 | fpR: 0.00800 | P: 0.98925 | R: 0.73600 | F1: 0.84355
# Epoch [170/2000] Training: DISC | Loss D: 0.45783, Loss G: 1.50075 | Accuracy: 0.92400 | fpR: 0.00000 | P: 1.00000 | R: 0.84800 | F1: 0.91725
# Epoch [171/2000] Training: DISC | Loss D: 0.45041, Loss G: 1.53106 | Accuracy: 0.90800 | fpR: 0.00000 | P: 1.00000 | R: 0.81600 | F1: 0.89818
# Epoch [172/2000] Training: DISC | Loss D: 0.44612, Loss G: 1.58753 | Accuracy: 0.90000 | fpR: 0.00000 | P: 1.00000 | R: 0.80000 | F1: 0.88840
# Epoch [173/2000] Training: DISC | Loss D: 0.44905, Loss G: 1.63172 | Accuracy: 0.87200 | fpR: 0.00000 | P: 1.00000 | R: 0.74400 | F1: 0.85272
# Epoch [174/2000] Training: DISC | Loss D: 0.43610, Loss G: 1.61346 | Accuracy: 0.89600 | fpR: 0.00000 | P: 1.00000 | R: 0.79200 | F1: 0.88344
# Epoch [175/2000] Training: DISC | Loss D: 0.43300, Loss G: 1.68025 | Accuracy: 0.88400 | fpR: 0.00000 | P: 1.00000 | R: 0.76800 | F1: 0.86829
# Epoch [176/2000] Training: DISC | Loss D: 0.41703, Loss G: 1.72336 | Accuracy: 0.88800 | fpR: 0.00000 | P: 1.00000 | R: 0.77600 | F1: 0.87338
# Epoch [177/2000] Training: DISC | Loss D: 0.41245, Loss G: 1.77725 | Accuracy: 0.90400 | fpR: 0.00000 | P: 1.00000 | R: 0.80800 | F1: 0.89331
# Epoch [178/2000] Training: DISC | Loss D: 0.41404, Loss G: 1.80727 | Accuracy: 0.87600 | fpR: 0.00000 | P: 1.00000 | R: 0.75200 | F1: 0.85796
# Epoch [179/2000] Training: DISC | Loss D: 0.40815, Loss G: 1.79943 | Accuracy: 0.91200 | fpR: 0.00000 | P: 1.00000 | R: 0.82400 | F1: 0.90301
# Epoch [180/2000] Training: DISC | Loss D: 0.40014, Loss G: 1.86516 | Accuracy: 0.89600 | fpR: 0.00000 | P: 1.00000 | R: 0.79200 | F1: 0.88344
# Epoch [181/2000] Training: DISC | Loss D: 0.39616, Loss G: 1.92324 | Accuracy: 0.90800 | fpR: 0.00000 | P: 1.00000 | R: 0.81600 | F1: 0.89818
# Epoch [182/2000] Training: DISC | Loss D: 0.38743, Loss G: 1.94161 | Accuracy: 0.93600 | fpR: 0.00000 | P: 1.00000 | R: 0.87200 | F1: 0.93113
#
# Pull Generator
#
# Epoch [183/2000] Training: GEN | Loss D: 0.39236, Loss G: 1.90936 | Accuracy: 0.94000 | fpR: 0.00000 | P: 1.00000 | R: 0.88000 | F1: 0.93567
# Epoch [184/2000] Training: GEN | Loss D: 0.40151, Loss G: 1.79041 | Accuracy: 0.91600 | fpR: 0.00000 | P: 1.00000 | R: 0.83200 | F1: 0.90780
# Epoch [185/2000] Training: GEN | Loss D: 0.41029, Loss G: 1.67065 | Accuracy: 0.91200 | fpR: 0.00800 | P: 0.99048 | R: 0.83200 | F1: 0.90385
# Epoch [186/2000] Training: GEN | Loss D: 0.42671, Loss G: 1.61597 | Accuracy: 0.90400 | fpR: 0.00800 | P: 0.99029 | R: 0.81600 | F1: 0.89424
# Epoch [187/2000] Training: GEN | Loss D: 0.42814, Loss G: 1.50054 | Accuracy: 0.91200 | fpR: 0.00000 | P: 1.00000 | R: 0.82400 | F1: 0.90301
# Epoch [188/2000] Training: GEN | Loss D: 0.44324, Loss G: 1.44400 | Accuracy: 0.95600 | fpR: 0.01600 | P: 0.98305 | R: 0.92800 | F1: 0.95423
# Epoch [189/2000] Training: GEN | Loss D: 0.44945, Loss G: 1.38535 | Accuracy: 0.92000 | fpR: 0.00800 | P: 0.99065 | R: 0.84800 | F1: 0.91330
# Epoch [190/2000] Training: GEN | Loss D: 0.45924, Loss G: 1.32531 | Accuracy: 0.92800 | fpR: 0.00000 | P: 1.00000 | R: 0.85600 | F1: 0.92192
# Epoch [191/2000] Training: GEN | Loss D: 0.46798, Loss G: 1.28657 | Accuracy: 0.88400 | fpR: 0.01600 | P: 0.98000 | R: 0.78400 | F1: 0.87062
# Epoch [192/2000] Training: GEN | Loss D: 0.46353, Loss G: 1.22340 | Accuracy: 0.91200 | fpR: 0.01600 | P: 0.98131 | R: 0.84000 | F1: 0.90468
# Epoch [193/2000] Training: GEN | Loss D: 0.48756, Loss G: 1.19103 | Accuracy: 0.89200 | fpR: 0.00800 | P: 0.99000 | R: 0.79200 | F1: 0.87951
# Epoch [194/2000] Training: GEN | Loss D: 0.50159, Loss G: 1.14458 | Accuracy: 0.90000 | fpR: 0.04800 | P: 0.94643 | R: 0.84800 | F1: 0.89402
# Epoch [195/2000] Training: GEN | Loss D: 0.51467, Loss G: 1.08085 | Accuracy: 0.90400 | fpR: 0.04000 | P: 0.95495 | R: 0.84800 | F1: 0.89781
# Epoch [196/2000] Training: GEN | Loss D: 0.51589, Loss G: 1.04010 | Accuracy: 0.89600 | fpR: 0.04800 | P: 0.94595 | R: 0.84000 | F1: 0.88933
# Epoch [197/2000] Training: GEN | Loss D: 0.54476, Loss G: 1.00995 | Accuracy: 0.89200 | fpR: 0.10400 | P: 0.89516 | R: 0.88800 | F1: 0.89107
# Epoch [198/2000] Training: GEN | Loss D: 0.54832, Loss G: 0.96494 | Accuracy: 0.81200 | fpR: 0.18400 | P: 0.81452 | R: 0.80800 | F1: 0.81075
# Epoch [199/2000] Training: GEN | Loss D: 0.57034, Loss G: 0.91557 | Accuracy: 0.77600 | fpR: 0.27200 | P: 0.75182 | R: 0.82400 | F1: 0.78576
# Epoch [200/2000] Training: GEN | Loss D: 0.58779, Loss G: 0.87806 | Accuracy: 0.78000 | fpR: 0.30400 | P: 0.73973 | R: 0.86400 | F1: 0.79655
# Epoch [201/2000] Training: GEN | Loss D: 0.60237, Loss G: 0.83002 | Accuracy: 0.78400 | fpR: 0.28000 | P: 0.75177 | R: 0.84800 | F1: 0.79649
# Epoch [202/2000] Training: GEN | Loss D: 0.61108, Loss G: 0.80112 | Accuracy: 0.73200 | fpR: 0.39200 | P: 0.68590 | R: 0.85600 | F1: 0.76107
# Epoch [203/2000] Training: GEN | Loss D: 0.63151, Loss G: 0.76620 | Accuracy: 0.68800 | fpR: 0.45600 | P: 0.64596 | R: 0.83200 | F1: 0.72678
# Epoch [204/2000] Training: GEN | Loss D: 0.63991, Loss G: 0.72826 | Accuracy: 0.64400 | fpR: 0.48800 | P: 0.61392 | R: 0.77600 | F1: 0.68502
# Epoch [205/2000] Training: GEN | Loss D: 0.65488, Loss G: 0.69587 | Accuracy: 0.58800 | fpR: 0.57600 | P: 0.56627 | R: 0.75200 | F1: 0.64556
# Epoch [206/2000] Training: GEN | Loss D: 0.66592, Loss G: 0.66934 | Accuracy: 0.60800 | fpR: 0.60800 | P: 0.57542 | R: 0.82400 | F1: 0.67715
#
# Push Generator
#
# Epoch [207/2000] Training: DISC | Loss D: 0.66086, Loss G: 0.69065 | Accuracy: 0.64000 | fpR: 0.58400 | P: 0.59669 | R: 0.86400 | F1: 0.70540
# Epoch [208/2000] Training: DISC | Loss D: 0.66335, Loss G: 0.70525 | Accuracy: 0.65200 | fpR: 0.53600 | P: 0.61047 | R: 0.84000 | F1: 0.70658
# Epoch [209/2000] Training: DISC | Loss D: 0.64307, Loss G: 0.73102 | Accuracy: 0.64800 | fpR: 0.50400 | P: 0.61350 | R: 0.80000 | F1: 0.69395
# Epoch [210/2000] Training: DISC | Loss D: 0.62993, Loss G: 0.75822 | Accuracy: 0.70000 | fpR: 0.44800 | P: 0.65432 | R: 0.84800 | F1: 0.73818
# Epoch [211/2000] Training: DISC | Loss D: 0.62097, Loss G: 0.77873 | Accuracy: 0.72000 | fpR: 0.43200 | P: 0.66871 | R: 0.87200 | F1: 0.75645
# Epoch [212/2000] Training: DISC | Loss D: 0.60733, Loss G: 0.79231 | Accuracy: 0.70000 | fpR: 0.31200 | P: 0.69531 | R: 0.71200 | F1: 0.70306
# Epoch [213/2000] Training: DISC | Loss D: 0.60436, Loss G: 0.82612 | Accuracy: 0.73200 | fpR: 0.34400 | P: 0.70139 | R: 0.80800 | F1: 0.75043
# Epoch [214/2000] Training: DISC | Loss D: 0.59611, Loss G: 0.84468 | Accuracy: 0.73600 | fpR: 0.30400 | P: 0.71852 | R: 0.77600 | F1: 0.74565
# Epoch [215/2000] Training: DISC | Loss D: 0.58360, Loss G: 0.86221 | Accuracy: 0.79600 | fpR: 0.21600 | P: 0.78906 | R: 0.80800 | F1: 0.79792
# Epoch [216/2000] Training: DISC | Loss D: 0.57606, Loss G: 0.89628 | Accuracy: 0.81600 | fpR: 0.16800 | P: 0.82645 | R: 0.80000 | F1: 0.81251
# Epoch [217/2000] Training: DISC | Loss D: 0.58296, Loss G: 0.90219 | Accuracy: 0.81600 | fpR: 0.13600 | P: 0.84956 | R: 0.76800 | F1: 0.80622
# Epoch [218/2000] Training: DISC | Loss D: 0.56561, Loss G: 0.92265 | Accuracy: 0.79600 | fpR: 0.19200 | P: 0.80328 | R: 0.78400 | F1: 0.79302
# Epoch [219/2000] Training: DISC | Loss D: 0.56494, Loss G: 0.95061 | Accuracy: 0.80800 | fpR: 0.16000 | P: 0.82906 | R: 0.77600 | F1: 0.80115
# Epoch [220/2000] Training: DISC | Loss D: 0.57481, Loss G: 0.96873 | Accuracy: 0.84000 | fpR: 0.11200 | P: 0.87611 | R: 0.79200 | F1: 0.83143
# Epoch [221/2000] Training: DISC | Loss D: 0.55419, Loss G: 0.97242 | Accuracy: 0.82000 | fpR: 0.11200 | P: 0.87037 | R: 0.75200 | F1: 0.80637
# Epoch [222/2000] Training: DISC | Loss D: 0.55341, Loss G: 0.97835 | Accuracy: 0.86000 | fpR: 0.07200 | P: 0.91667 | R: 0.79200 | F1: 0.84929
# Epoch [223/2000] Training: DISC | Loss D: 0.53944, Loss G: 1.02516 | Accuracy: 0.83600 | fpR: 0.04800 | P: 0.93750 | R: 0.72000 | F1: 0.81399
# Epoch [224/2000] Training: DISC | Loss D: 0.53611, Loss G: 1.02891 | Accuracy: 0.88400 | fpR: 0.06400 | P: 0.92857 | R: 0.83200 | F1: 0.87714
# Epoch [225/2000] Training: DISC | Loss D: 0.53840, Loss G: 1.04631 | Accuracy: 0.88400 | fpR: 0.02400 | P: 0.97059 | R: 0.79200 | F1: 0.87175
# Epoch [226/2000] Training: DISC | Loss D: 0.52884, Loss G: 1.05411 | Accuracy: 0.84800 | fpR: 0.06400 | P: 0.92233 | R: 0.76000 | F1: 0.83284
# Epoch [227/2000] Training: DISC | Loss D: 0.52660, Loss G: 1.07121 | Accuracy: 0.86400 | fpR: 0.06400 | P: 0.92523 | R: 0.79200 | F1: 0.85295
# Epoch [228/2000] Training: DISC | Loss D: 0.52248, Loss G: 1.09179 | Accuracy: 0.86400 | fpR: 0.04800 | P: 0.94175 | R: 0.77600 | F1: 0.85038
# Epoch [229/2000] Training: DISC | Loss D: 0.51119, Loss G: 1.10459 | Accuracy: 0.86400 | fpR: 0.04000 | P: 0.95050 | R: 0.76800 | F1: 0.84906
# Epoch [230/2000] Training: DISC | Loss D: 0.51420, Loss G: 1.11125 | Accuracy: 0.88000 | fpR: 0.04800 | P: 0.94393 | R: 0.80800 | F1: 0.87019
# Epoch [231/2000] Training: DISC | Loss D: 0.49591, Loss G: 1.13339 | Accuracy: 0.90400 | fpR: 0.03200 | P: 0.96330 | R: 0.84000 | F1: 0.89694
# Epoch [232/2000] Training: DISC | Loss D: 0.50236, Loss G: 1.13992 | Accuracy: 0.90000 | fpR: 0.02400 | P: 0.97170 | R: 0.82400 | F1: 0.89128
# Epoch [233/2000] Training: DISC | Loss D: 0.49706, Loss G: 1.16429 | Accuracy: 0.93600 | fpR: 0.03200 | P: 0.96581 | R: 0.90400 | F1: 0.93339
#
# Pull Generator
#
# Epoch [234/2000] Training: GEN | Loss D: 0.50535, Loss G: 1.11117 | Accuracy: 0.87600 | fpR: 0.02400 | P: 0.97000 | R: 0.77600 | F1: 0.86173
# Epoch [235/2000] Training: GEN | Loss D: 0.52811, Loss G: 1.02450 | Accuracy: 0.86000 | fpR: 0.07200 | P: 0.91667 | R: 0.79200 | F1: 0.84929
# Epoch [236/2000] Training: GEN | Loss D: 0.55625, Loss G: 0.95897 | Accuracy: 0.84400 | fpR: 0.18400 | P: 0.82576 | R: 0.87200 | F1: 0.84775
# Epoch [237/2000] Training: GEN | Loss D: 0.57861, Loss G: 0.86196 | Accuracy: 0.80000 | fpR: 0.24000 | P: 0.77778 | R: 0.84000 | F1: 0.80719
# Epoch [238/2000] Training: GEN | Loss D: 0.61167, Loss G: 0.79047 | Accuracy: 0.70400 | fpR: 0.40000 | P: 0.66887 | R: 0.80800 | F1: 0.73139
# Epoch [239/2000] Training: GEN | Loss D: 0.63862, Loss G: 0.72446 | Accuracy: 0.69200 | fpR: 0.43200 | P: 0.65385 | R: 0.81600 | F1: 0.72549
# Epoch [240/2000] Training: GEN | Loss D: 0.66032, Loss G: 0.68542 | Accuracy: 0.64000 | fpR: 0.57600 | P: 0.59777 | R: 0.85600 | F1: 0.70346
# Epoch [241/2000] Training: GEN | Loss D: 0.68261, Loss G: 0.64526 | Accuracy: 0.58400 | fpR: 0.61600 | P: 0.56000 | R: 0.78400 | F1: 0.65285
#
# Push Generator
#
# Epoch [242/2000] Training: DISC | Loss D: 0.68053, Loss G: 0.64812 | Accuracy: 0.58800 | fpR: 0.68000 | P: 0.55729 | R: 0.85600 | F1: 0.67460
# Epoch [243/2000] Training: DISC | Loss D: 0.67248, Loss G: 0.65415 | Accuracy: 0.59600 | fpR: 0.60800 | P: 0.56818 | R: 0.80000 | F1: 0.66397
# Epoch [244/2000] Training: DISC | Loss D: 0.66442, Loss G: 0.67585 | Accuracy: 0.63200 | fpR: 0.54400 | P: 0.59763 | R: 0.80800 | F1: 0.68659
# Epoch [245/2000] Training: DISC | Loss D: 0.65256, Loss G: 0.69857 | Accuracy: 0.66400 | fpR: 0.52000 | P: 0.61988 | R: 0.84800 | F1: 0.71573
# Epoch [246/2000] Training: DISC | Loss D: 0.65675, Loss G: 0.71725 | Accuracy: 0.60800 | fpR: 0.54400 | P: 0.58282 | R: 0.76000 | F1: 0.65923
# Epoch [247/2000] Training: DISC | Loss D: 0.64808, Loss G: 0.73197 | Accuracy: 0.65600 | fpR: 0.48000 | P: 0.62264 | R: 0.79200 | F1: 0.69669
# Epoch [248/2000] Training: DISC | Loss D: 0.64385, Loss G: 0.75834 | Accuracy: 0.62800 | fpR: 0.52000 | P: 0.59877 | R: 0.77600 | F1: 0.67547
# Epoch [249/2000] Training: DISC | Loss D: 0.64940, Loss G: 0.75583 | Accuracy: 0.62400 | fpR: 0.47200 | P: 0.60403 | R: 0.72000 | F1: 0.65644
# Epoch [250/2000] Training: DISC | Loss D: 0.63546, Loss G: 0.75253 | Accuracy: 0.68800 | fpR: 0.37600 | P: 0.66667 | R: 0.75200 | F1: 0.70627
# Epoch [251/2000] Training: DISC | Loss D: 0.63459, Loss G: 0.76946 | Accuracy: 0.78400 | fpR: 0.25600 | P: 0.76296 | R: 0.82400 | F1: 0.79181
# Epoch [252/2000] Training: DISC | Loss D: 0.62867, Loss G: 0.79216 | Accuracy: 0.71600 | fpR: 0.35200 | P: 0.69014 | R: 0.78400 | F1: 0.73358
# Epoch [253/2000] Training: DISC | Loss D: 0.63034, Loss G: 0.81253 | Accuracy: 0.72000 | fpR: 0.30400 | P: 0.70992 | R: 0.74400 | F1: 0.72606
# Epoch [254/2000] Training: DISC | Loss D: 0.61259, Loss G: 0.83028 | Accuracy: 0.71200 | fpR: 0.27200 | P: 0.71901 | R: 0.69600 | F1: 0.70682
# Epoch [255/2000] Training: DISC | Loss D: 0.61365, Loss G: 0.84689 | Accuracy: 0.72800 | fpR: 0.24000 | P: 0.74359 | R: 0.69600 | F1: 0.71851
# Epoch [256/2000] Training: DISC | Loss D: 0.62257, Loss G: 0.84111 | Accuracy: 0.73200 | fpR: 0.20000 | P: 0.76852 | R: 0.66400 | F1: 0.71195
# Epoch [257/2000] Training: DISC | Loss D: 0.61600, Loss G: 0.85457 | Accuracy: 0.73200 | fpR: 0.19200 | P: 0.77358 | R: 0.65600 | F1: 0.70946
# Epoch [258/2000] Training: DISC | Loss D: 0.61792, Loss G: 0.87235 | Accuracy: 0.78400 | fpR: 0.12000 | P: 0.85149 | R: 0.68800 | F1: 0.76057
# Epoch [259/2000] Training: DISC | Loss D: 0.58984, Loss G: 0.87950 | Accuracy: 0.76000 | fpR: 0.14400 | P: 0.82178 | R: 0.66400 | F1: 0.73402
# Epoch [260/2000] Training: DISC | Loss D: 0.60077, Loss G: 0.89022 | Accuracy: 0.76800 | fpR: 0.17600 | P: 0.80180 | R: 0.71200 | F1: 0.75374
# Epoch [261/2000] Training: DISC | Loss D: 0.60149, Loss G: 0.90842 | Accuracy: 0.75600 | fpR: 0.16800 | P: 0.80189 | R: 0.68000 | F1: 0.73543
# Epoch [262/2000] Training: DISC | Loss D: 0.60656, Loss G: 0.89601 | Accuracy: 0.77200 | fpR: 0.19200 | P: 0.79310 | R: 0.73600 | F1: 0.76299
# Epoch [263/2000] Training: DISC | Loss D: 0.58924, Loss G: 0.90943 | Accuracy: 0.79600 | fpR: 0.11200 | P: 0.86275 | R: 0.70400 | F1: 0.77484
# Epoch [264/2000] Training: DISC | Loss D: 0.58927, Loss G: 0.93106 | Accuracy: 0.80400 | fpR: 0.09600 | P: 0.88000 | R: 0.70400 | F1: 0.78173
# Epoch [265/2000] Training: DISC | Loss D: 0.58797, Loss G: 0.90396 | Accuracy: 0.79600 | fpR: 0.10400 | P: 0.87000 | R: 0.69600 | F1: 0.77284
# Epoch [266/2000] Training: DISC | Loss D: 0.58592, Loss G: 0.94062 | Accuracy: 0.79600 | fpR: 0.12800 | P: 0.84906 | R: 0.72000 | F1: 0.77872
# Epoch [267/2000] Training: DISC | Loss D: 0.55973, Loss G: 0.92950 | Accuracy: 0.81200 | fpR: 0.08000 | P: 0.89796 | R: 0.70400 | F1: 0.78875
# Epoch [268/2000] Training: DISC | Loss D: 0.57273, Loss G: 0.95152 | Accuracy: 0.77200 | fpR: 0.09600 | P: 0.86957 | R: 0.64000 | F1: 0.73684
# Epoch [269/2000] Training: DISC | Loss D: 0.56382, Loss G: 0.95925 | Accuracy: 0.82400 | fpR: 0.09600 | P: 0.88571 | R: 0.74400 | F1: 0.80820
# Epoch [270/2000] Training: DISC | Loss D: 0.56685, Loss G: 0.97652 | Accuracy: 0.84000 | fpR: 0.05600 | P: 0.92929 | R: 0.73600 | F1: 0.82094
# Epoch [271/2000] Training: DISC | Loss D: 0.56125, Loss G: 0.96152 | Accuracy: 0.80400 | fpR: 0.08000 | P: 0.89583 | R: 0.68800 | F1: 0.77779
# Epoch [272/2000] Training: DISC | Loss D: 0.55529, Loss G: 0.97102 | Accuracy: 0.76800 | fpR: 0.10400 | P: 0.86022 | R: 0.64000 | F1: 0.73346
# Epoch [273/2000] Training: DISC | Loss D: 0.55083, Loss G: 0.99798 | Accuracy: 0.78000 | fpR: 0.08800 | P: 0.88043 | R: 0.64800 | F1: 0.74606
# Epoch [274/2000] Training: DISC | Loss D: 0.55656, Loss G: 1.00948 | Accuracy: 0.84400 | fpR: 0.04800 | P: 0.93878 | R: 0.73600 | F1: 0.82462
# Epoch [275/2000] Training: DISC | Loss D: 0.54352, Loss G: 0.99568 | Accuracy: 0.86400 | fpR: 0.04800 | P: 0.94175 | R: 0.77600 | F1: 0.85038
# Epoch [276/2000] Training: DISC | Loss D: 0.54463, Loss G: 1.01976 | Accuracy: 0.83600 | fpR: 0.06400 | P: 0.92000 | R: 0.73600 | F1: 0.81728
# Epoch [277/2000] Training: DISC | Loss D: 0.53159, Loss G: 1.00335 | Accuracy: 0.79600 | fpR: 0.06400 | P: 0.91111 | R: 0.65600 | F1: 0.76230
# Epoch [278/2000] Training: DISC | Loss D: 0.53489, Loss G: 1.02909 | Accuracy: 0.84800 | fpR: 0.03200 | P: 0.95789 | R: 0.72800 | F1: 0.82678
# Epoch [279/2000] Training: DISC | Loss D: 0.52635, Loss G: 1.02877 | Accuracy: 0.83600 | fpR: 0.06400 | P: 0.92000 | R: 0.73600 | F1: 0.81728
# Epoch [280/2000] Training: DISC | Loss D: 0.51537, Loss G: 1.04933 | Accuracy: 0.84800 | fpR: 0.05600 | P: 0.93069 | R: 0.75200 | F1: 0.83136
# Epoch [281/2000] Training: DISC | Loss D: 0.52190, Loss G: 1.03014 | Accuracy: 0.83600 | fpR: 0.07200 | P: 0.91176 | R: 0.74400 | F1: 0.81889
# Epoch [282/2000] Training: DISC | Loss D: 0.51210, Loss G: 1.04644 | Accuracy: 0.86000 | fpR: 0.07200 | P: 0.91667 | R: 0.79200 | F1: 0.84929
# Epoch [283/2000] Training: DISC | Loss D: 0.50995, Loss G: 1.04563 | Accuracy: 0.80800 | fpR: 0.09600 | P: 0.88119 | R: 0.71200 | F1: 0.78712
# Epoch [284/2000] Training: DISC | Loss D: 0.51253, Loss G: 1.05453 | Accuracy: 0.82000 | fpR: 0.08800 | P: 0.89216 | R: 0.72800 | F1: 0.80127
# Epoch [285/2000] Training: DISC | Loss D: 0.50740, Loss G: 1.04536 | Accuracy: 0.84800 | fpR: 0.03200 | P: 0.95789 | R: 0.72800 | F1: 0.82678
# Epoch [286/2000] Training: DISC | Loss D: 0.52575, Loss G: 1.07263 | Accuracy: 0.85200 | fpR: 0.06400 | P: 0.92308 | R: 0.76800 | F1: 0.83793
# Epoch [287/2000] Training: DISC | Loss D: 0.51697, Loss G: 1.06998 | Accuracy: 0.83200 | fpR: 0.05600 | P: 0.92784 | R: 0.72000 | F1: 0.81032
# Epoch [288/2000] Training: DISC | Loss D: 0.51053, Loss G: 1.09503 | Accuracy: 0.85200 | fpR: 0.06400 | P: 0.92308 | R: 0.76800 | F1: 0.83793
# Epoch [289/2000] Training: DISC | Loss D: 0.49523, Loss G: 1.09925 | Accuracy: 0.88000 | fpR: 0.04800 | P: 0.94393 | R: 0.80800 | F1: 0.87019
# Epoch [290/2000] Training: DISC | Loss D: 0.50051, Loss G: 1.11915 | Accuracy: 0.86400 | fpR: 0.05600 | P: 0.93333 | R: 0.78400 | F1: 0.85168
# Epoch [291/2000] Training: DISC | Loss D: 0.49567, Loss G: 1.10585 | Accuracy: 0.85600 | fpR: 0.06400 | P: 0.92381 | R: 0.77600 | F1: 0.84298
# Epoch [292/2000] Training: DISC | Loss D: 0.50149, Loss G: 1.12389 | Accuracy: 0.84000 | fpR: 0.04800 | P: 0.93814 | R: 0.72800 | F1: 0.81933
# Epoch [293/2000] Training: DISC | Loss D: 0.49680, Loss G: 1.12774 | Accuracy: 0.85600 | fpR: 0.04000 | P: 0.94949 | R: 0.75200 | F1: 0.83879
# Epoch [294/2000] Training: DISC | Loss D: 0.49040, Loss G: 1.11090 | Accuracy: 0.86800 | fpR: 0.05600 | P: 0.93396 | R: 0.79200 | F1: 0.85665
# Epoch [295/2000] Training: DISC | Loss D: 0.49508, Loss G: 1.13596 | Accuracy: 0.88400 | fpR: 0.02400 | P: 0.97059 | R: 0.79200 | F1: 0.87175
# Epoch [296/2000] Training: DISC | Loss D: 0.48901, Loss G: 1.14085 | Accuracy: 0.83600 | fpR: 0.04800 | P: 0.93750 | R: 0.72000 | F1: 0.81399
# Epoch [297/2000] Training: DISC | Loss D: 0.46434, Loss G: 1.17128 | Accuracy: 0.87600 | fpR: 0.05600 | P: 0.93519 | R: 0.80800 | F1: 0.86646
# Epoch [298/2000] Training: DISC | Loss D: 0.48136, Loss G: 1.14933 | Accuracy: 0.87200 | fpR: 0.05600 | P: 0.93458 | R: 0.80000 | F1: 0.86157
# Epoch [299/2000] Training: DISC | Loss D: 0.46389, Loss G: 1.14772 | Accuracy: 0.88400 | fpR: 0.04800 | P: 0.94444 | R: 0.81600 | F1: 0.87504
# Epoch [300/2000] Training: DISC | Loss D: 0.47353, Loss G: 1.17338 | Accuracy: 0.86400 | fpR: 0.04000 | P: 0.95050 | R: 0.76800 | F1: 0.84906
# Epoch [301/2000] Training: DISC | Loss D: 0.48641, Loss G: 1.17380 | Accuracy: 0.88400 | fpR: 0.04000 | P: 0.95283 | R: 0.80800 | F1: 0.87396
# Epoch [302/2000] Training: DISC | Loss D: 0.45388, Loss G: 1.19250 | Accuracy: 0.90400 | fpR: 0.02400 | P: 0.97196 | R: 0.83200 | F1: 0.89606
# Epoch [303/2000] Training: DISC | Loss D: 0.46267, Loss G: 1.20322 | Accuracy: 0.88800 | fpR: 0.02400 | P: 0.97087 | R: 0.80000 | F1: 0.87670
# Epoch [304/2000] Training: DISC | Loss D: 0.44585, Loss G: 1.21022 | Accuracy: 0.85200 | fpR: 0.08800 | P: 0.90000 | R: 0.79200 | F1: 0.84206
# Epoch [305/2000] Training: DISC | Loss D: 0.44100, Loss G: 1.22626 | Accuracy: 0.90000 | fpR: 0.05600 | P: 0.93860 | R: 0.85600 | F1: 0.89490
#
# Pull Generator
#
# Epoch [306/2000] Training: GEN | Loss D: 0.47239, Loss G: 1.06880 | Accuracy: 0.86000 | fpR: 0.11200 | P: 0.88136 | R: 0.83200 | F1: 0.85547
# Epoch [307/2000] Training: GEN | Loss D: 0.55550, Loss G: 0.94426 | Accuracy: 0.79200 | fpR: 0.23200 | P: 0.77863 | R: 0.81600 | F1: 0.79638
# Epoch [308/2000] Training: GEN | Loss D: 0.59736, Loss G: 0.77025 | Accuracy: 0.66800 | fpR: 0.44000 | P: 0.63816 | R: 0.77600 | F1: 0.69987
# Epoch [309/2000] Training: GEN | Loss D: 0.66457, Loss G: 0.65519 | Accuracy: 0.58800 | fpR: 0.68000 | P: 0.55729 | R: 0.85600 | F1: 0.67460
#
# Push Generator
#
# Epoch [310/2000] Training: DISC | Loss D: 0.65656, Loss G: 0.68036 | Accuracy: 0.58800 | fpR: 0.68000 | P: 0.55729 | R: 0.85600 | F1: 0.67460
# Epoch [311/2000] Training: DISC | Loss D: 0.66111, Loss G: 0.68602 | Accuracy: 0.58000 | fpR: 0.56800 | P: 0.56173 | R: 0.72800 | F1: 0.63366
# Epoch [312/2000] Training: DISC | Loss D: 0.62232, Loss G: 0.74371 | Accuracy: 0.62400 | fpR: 0.49600 | P: 0.60000 | R: 0.74400 | F1: 0.66379
# Epoch [313/2000] Training: DISC | Loss D: 0.61309, Loss G: 0.78717 | Accuracy: 0.64400 | fpR: 0.45600 | P: 0.62000 | R: 0.74400 | F1: 0.67587
# Epoch [314/2000] Training: DISC | Loss D: 0.61531, Loss G: 0.82690 | Accuracy: 0.67600 | fpR: 0.28000 | P: 0.69298 | R: 0.63200 | F1: 0.66059
# Epoch [315/2000] Training: DISC | Loss D: 0.59851, Loss G: 0.84423 | Accuracy: 0.66000 | fpR: 0.31200 | P: 0.66949 | R: 0.63200 | F1: 0.64971
# Epoch [316/2000] Training: DISC | Loss D: 0.59588, Loss G: 0.86913 | Accuracy: 0.70000 | fpR: 0.27200 | P: 0.71186 | R: 0.67200 | F1: 0.69086
# Epoch [317/2000] Training: DISC | Loss D: 0.57740, Loss G: 0.90115 | Accuracy: 0.70800 | fpR: 0.23200 | P: 0.73636 | R: 0.64800 | F1: 0.68886
# Epoch [318/2000] Training: DISC | Loss D: 0.57336, Loss G: 0.93004 | Accuracy: 0.73200 | fpR: 0.24800 | P: 0.74167 | R: 0.71200 | F1: 0.72603
# Epoch [319/2000] Training: DISC | Loss D: 0.59392, Loss G: 0.95845 | Accuracy: 0.69200 | fpR: 0.20800 | P: 0.74000 | R: 0.59200 | F1: 0.65728
# Epoch [320/2000] Training: DISC | Loss D: 0.60425, Loss G: 0.96365 | Accuracy: 0.74400 | fpR: 0.16000 | P: 0.80198 | R: 0.64800 | F1: 0.71632
# Epoch [321/2000] Training: DISC | Loss D: 0.58212, Loss G: 0.95770 | Accuracy: 0.74400 | fpR: 0.19200 | P: 0.77982 | R: 0.68000 | F1: 0.72600
# Epoch [322/2000] Training: DISC | Loss D: 0.54826, Loss G: 0.96493 | Accuracy: 0.72400 | fpR: 0.18400 | P: 0.77451 | R: 0.63200 | F1: 0.69554
# Epoch [323/2000] Training: DISC | Loss D: 0.56776, Loss G: 0.97581 | Accuracy: 0.70400 | fpR: 0.16000 | P: 0.78022 | R: 0.56800 | F1: 0.65692
# Epoch [324/2000] Training: DISC | Loss D: 0.55766, Loss G: 0.99002 | Accuracy: 0.72400 | fpR: 0.12800 | P: 0.81818 | R: 0.57600 | F1: 0.67557
# Epoch [325/2000] Training: DISC | Loss D: 0.56217, Loss G: 1.00010 | Accuracy: 0.75200 | fpR: 0.15200 | P: 0.81188 | R: 0.65600 | F1: 0.72517
# Epoch [326/2000] Training: DISC | Loss D: 0.55310, Loss G: 0.97670 | Accuracy: 0.72400 | fpR: 0.16000 | P: 0.79167 | R: 0.60800 | F1: 0.68729
# Epoch [327/2000] Training: DISC | Loss D: 0.55719, Loss G: 1.01394 | Accuracy: 0.73600 | fpR: 0.17600 | P: 0.78641 | R: 0.64800 | F1: 0.71003
# Epoch [328/2000] Training: DISC | Loss D: 0.56365, Loss G: 1.01555 | Accuracy: 0.69600 | fpR: 0.18400 | P: 0.75789 | R: 0.57600 | F1: 0.65406
# Epoch [329/2000] Training: DISC | Loss D: 0.56511, Loss G: 1.04193 | Accuracy: 0.70800 | fpR: 0.22400 | P: 0.74074 | R: 0.64000 | F1: 0.68620
# Epoch [330/2000] Training: DISC | Loss D: 0.56028, Loss G: 1.02947 | Accuracy: 0.76400 | fpR: 0.13600 | P: 0.83000 | R: 0.66400 | F1: 0.73728
# Epoch [331/2000] Training: DISC | Loss D: 0.55401, Loss G: 1.02774 | Accuracy: 0.70800 | fpR: 0.16800 | P: 0.77660 | R: 0.58400 | F1: 0.66618
# Epoch [332/2000] Training: DISC | Loss D: 0.52764, Loss G: 1.03909 | Accuracy: 0.81600 | fpR: 0.07200 | P: 0.90722 | R: 0.70400 | F1: 0.79230
# Epoch [333/2000] Training: DISC | Loss D: 0.54762, Loss G: 1.02381 | Accuracy: 0.76000 | fpR: 0.14400 | P: 0.82178 | R: 0.66400 | F1: 0.73402
# Epoch [334/2000] Training: DISC | Loss D: 0.54016, Loss G: 1.00229 | Accuracy: 0.76400 | fpR: 0.15200 | P: 0.81731 | R: 0.68000 | F1: 0.74186
# Epoch [335/2000] Training: DISC | Loss D: 0.52307, Loss G: 1.07601 | Accuracy: 0.82000 | fpR: 0.06400 | P: 0.91667 | R: 0.70400 | F1: 0.79589
# Epoch [336/2000] Training: DISC | Loss D: 0.52538, Loss G: 1.03089 | Accuracy: 0.79200 | fpR: 0.07200 | P: 0.90110 | R: 0.65600 | F1: 0.75877
# Epoch [337/2000] Training: DISC | Loss D: 0.51827, Loss G: 1.06263 | Accuracy: 0.81600 | fpR: 0.12000 | P: 0.86239 | R: 0.75200 | F1: 0.80292
# Epoch [338/2000] Training: DISC | Loss D: 0.52959, Loss G: 1.04150 | Accuracy: 0.76000 | fpR: 0.10400 | P: 0.85714 | R: 0.62400 | F1: 0.72173
# ...
# Epoch [1892/2000] Training: DISC | Loss D: 0.45143, Loss G: 1.51195 | Accuracy: 0.79200 | fpR: 0.13600 | P: 0.84112 | R: 0.72000 | F1: 0.77537
# Epoch [1893/2000] Training: DISC | Loss D: 0.45223, Loss G: 1.51243 | Accuracy: 0.84400 | fpR: 0.10400 | P: 0.88393 | R: 0.79200 | F1: 0.83494
# Epoch [1894/2000] Training: DISC | Loss D: 0.45188, Loss G: 1.31990 | Accuracy: 0.78000 | fpR: 0.14400 | P: 0.83019 | R: 0.70400 | F1: 0.76141
# Epoch [1895/2000] Training: DISC | Loss D: 0.40397, Loss G: 1.52476 | Accuracy: 0.83600 | fpR: 0.04800 | P: 0.93750 | R: 0.72000 | F1: 0.81399
# Epoch [1896/2000] Training: DISC | Loss D: 0.43085, Loss G: 1.49525 | Accuracy: 0.82800 | fpR: 0.07200 | P: 0.91000 | R: 0.72800 | F1: 0.80840
# Epoch [1897/2000] Training: DISC | Loss D: 0.42644, Loss G: 1.59557 | Accuracy: 0.77200 | fpR: 0.15200 | P: 0.82075 | R: 0.69600 | F1: 0.75275
# Epoch [1898/2000] Training: DISC | Loss D: 0.39091, Loss G: 1.51888 | Accuracy: 0.85200 | fpR: 0.07200 | P: 0.91509 | R: 0.77600 | F1: 0.83933
# Epoch [1899/2000] Training: DISC | Loss D: 0.41281, Loss G: 1.61593 | Accuracy: 0.86400 | fpR: 0.08000 | P: 0.90991 | R: 0.80800 | F1: 0.85543
# Epoch [1900/2000] Training: DISC | Loss D: 0.41884, Loss G: 1.50977 | Accuracy: 0.81600 | fpR: 0.13600 | P: 0.84956 | R: 0.76800 | F1: 0.80622
# Epoch [1901/2000] Training: DISC | Loss D: 0.37951, Loss G: 1.46614 | Accuracy: 0.84800 | fpR: 0.17600 | P: 0.83206 | R: 0.87200 | F1: 0.85106
#
# Pull Generator
#
# Epoch [1902/2000] Training: GEN | Loss D: 0.47308, Loss G: 1.34099 | Accuracy: 0.84400 | fpR: 0.11200 | P: 0.87719 | R: 0.80000 | F1: 0.83632
# Epoch [1903/2000] Training: GEN | Loss D: 0.53307, Loss G: 1.05498 | Accuracy: 0.70400 | fpR: 0.31200 | P: 0.69767 | R: 0.72000 | F1: 0.70816
# Epoch [1904/2000] Training: GEN | Loss D: 0.58485, Loss G: 0.95171 | Accuracy: 0.68800 | fpR: 0.35200 | P: 0.67407 | R: 0.72800 | F1: 0.69950
# Epoch [1905/2000] Training: GEN | Loss D: 0.58434, Loss G: 0.82337 | Accuracy: 0.63600 | fpR: 0.56800 | P: 0.59659 | R: 0.84000 | F1: 0.69719
# Epoch [1906/2000] Training: GEN | Loss D: 0.62992, Loss G: 0.88513 | Accuracy: 0.59600 | fpR: 0.63200 | P: 0.56593 | R: 0.82400 | F1: 0.67053
#
# Push Generator
#
# Epoch [1907/2000] Training: DISC | Loss D: 0.59252, Loss G: 0.85676 | Accuracy: 0.61200 | fpR: 0.52000 | P: 0.58861 | R: 0.74400 | F1: 0.65675
# Epoch [1908/2000] Training: DISC | Loss D: 0.60822, Loss G: 0.94837 | Accuracy: 0.69200 | fpR: 0.32800 | P: 0.68462 | R: 0.71200 | F1: 0.69754
# Epoch [1909/2000] Training: DISC | Loss D: 0.49815, Loss G: 1.17667 | Accuracy: 0.67600 | fpR: 0.31200 | P: 0.68033 | R: 0.66400 | F1: 0.67157
# Epoch [1910/2000] Training: DISC | Loss D: 0.54385, Loss G: 1.23633 | Accuracy: 0.66800 | fpR: 0.21600 | P: 0.71875 | R: 0.55200 | F1: 0.62394
# Epoch [1911/2000] Training: DISC | Loss D: 0.48580, Loss G: 1.27535 | Accuracy: 0.71200 | fpR: 0.21600 | P: 0.74766 | R: 0.64000 | F1: 0.68916
# Epoch [1912/2000] Training: DISC | Loss D: 0.49887, Loss G: 1.29472 | Accuracy: 0.72400 | fpR: 0.23200 | P: 0.74561 | R: 0.68000 | F1: 0.71080
# Epoch [1913/2000] Training: DISC | Loss D: 0.51577, Loss G: 1.18689 | Accuracy: 0.77600 | fpR: 0.20000 | P: 0.78992 | R: 0.75200 | F1: 0.76999
# Epoch [1914/2000] Training: DISC | Loss D: 0.47905, Loss G: 1.21261 | Accuracy: 0.78800 | fpR: 0.20000 | P: 0.79508 | R: 0.77600 | F1: 0.78493
# Epoch [1915/2000] Training: DISC | Loss D: 0.49328, Loss G: 1.28625 | Accuracy: 0.74000 | fpR: 0.17600 | P: 0.78846 | R: 0.65600 | F1: 0.71566
# Epoch [1916/2000] Training: DISC | Loss D: 0.44137, Loss G: 1.32013 | Accuracy: 0.79600 | fpR: 0.15200 | P: 0.83036 | R: 0.74400 | F1: 0.78431
# Epoch [1917/2000] Training: DISC | Loss D: 0.46627, Loss G: 1.26433 | Accuracy: 0.80400 | fpR: 0.12000 | P: 0.85849 | R: 0.72800 | F1: 0.78738
# Epoch [1918/2000] Training: DISC | Loss D: 0.50408, Loss G: 1.31284 | Accuracy: 0.77600 | fpR: 0.18400 | P: 0.80000 | R: 0.73600 | F1: 0.76617
# Epoch [1919/2000] Training: DISC | Loss D: 0.47682, Loss G: 1.31291 | Accuracy: 0.73200 | fpR: 0.20800 | P: 0.76364 | R: 0.67200 | F1: 0.71440
# Epoch [1920/2000] Training: DISC | Loss D: 0.45237, Loss G: 1.33037 | Accuracy: 0.78000 | fpR: 0.14400 | P: 0.83019 | R: 0.70400 | F1: 0.76141
# Epoch [1921/2000] Training: DISC | Loss D: 0.45856, Loss G: 1.27027 | Accuracy: 0.81200 | fpR: 0.13600 | P: 0.84821 | R: 0.76000 | F1: 0.80119
# Epoch [1922/2000] Training: DISC | Loss D: 0.48556, Loss G: 1.38911 | Accuracy: 0.84800 | fpR: 0.11200 | P: 0.87826 | R: 0.80800 | F1: 0.84117
# Epoch [1923/2000] Training: DISC | Loss D: 0.42642, Loss G: 1.39383 | Accuracy: 0.77600 | fpR: 0.16800 | P: 0.81081 | R: 0.72000 | F1: 0.76221
# Epoch [1924/2000] Training: DISC | Loss D: 0.42226, Loss G: 1.33909 | Accuracy: 0.86000 | fpR: 0.09600 | P: 0.89474 | R: 0.81600 | F1: 0.85306
# Epoch [1925/2000] Training: DISC | Loss D: 0.43090, Loss G: 1.42342 | Accuracy: 0.83200 | fpR: 0.13600 | P: 0.85470 | R: 0.80000 | F1: 0.82595
# Epoch [1926/2000] Training: DISC | Loss D: 0.44258, Loss G: 1.41719 | Accuracy: 0.80400 | fpR: 0.16800 | P: 0.82203 | R: 0.77600 | F1: 0.79785
# Epoch [1927/2000] Training: DISC | Loss D: 0.42470, Loss G: 1.42165 | Accuracy: 0.82400 | fpR: 0.10400 | P: 0.87850 | R: 0.75200 | F1: 0.80985
# Epoch [1928/2000] Training: DISC | Loss D: 0.43514, Loss G: 1.42516 | Accuracy: 0.84800 | fpR: 0.08800 | P: 0.89908 | R: 0.78400 | F1: 0.83711
# Epoch [1929/2000] Training: DISC | Loss D: 0.42954, Loss G: 1.44612 | Accuracy: 0.84800 | fpR: 0.12000 | P: 0.87179 | R: 0.81600 | F1: 0.84248
# Epoch [1930/2000] Training: DISC | Loss D: 0.40021, Loss G: 1.50452 | Accuracy: 0.86400 | fpR: 0.08000 | P: 0.90991 | R: 0.80800 | F1: 0.85543
# Epoch [1931/2000] Training: DISC | Loss D: 0.38115, Loss G: 1.36858 | Accuracy: 0.86000 | fpR: 0.11200 | P: 0.88136 | R: 0.83200 | F1: 0.85547
# Epoch [1932/2000] Training: DISC | Loss D: 0.36797, Loss G: 1.50527 | Accuracy: 0.83600 | fpR: 0.18400 | P: 0.82308 | R: 0.85600 | F1: 0.83872
#
# Pull Generator
#
# Epoch [1933/2000] Training: GEN | Loss D: 0.45692, Loss G: 1.32764 | Accuracy: 0.80800 | fpR: 0.12800 | P: 0.85321 | R: 0.74400 | F1: 0.79437
# Epoch [1934/2000] Training: GEN | Loss D: 0.51421, Loss G: 1.20124 | Accuracy: 0.76800 | fpR: 0.28800 | P: 0.74101 | R: 0.82400 | F1: 0.77980
# Epoch [1935/2000] Training: GEN | Loss D: 0.54648, Loss G: 1.07226 | Accuracy: 0.70800 | fpR: 0.38400 | P: 0.67568 | R: 0.80000 | F1: 0.73210
# Epoch [1936/2000] Training: GEN | Loss D: 0.57353, Loss G: 0.97344 | Accuracy: 0.73200 | fpR: 0.40000 | P: 0.68354 | R: 0.86400 | F1: 0.76276
# Epoch [1937/2000] Training: GEN | Loss D: 0.59262, Loss G: 0.95286 | Accuracy: 0.70400 | fpR: 0.38400 | P: 0.67347 | R: 0.79200 | F1: 0.72744
# Epoch [1938/2000] Training: GEN | Loss D: 0.61841, Loss G: 0.89910 | Accuracy: 0.67200 | fpR: 0.47200 | P: 0.63354 | R: 0.81600 | F1: 0.71279
# Epoch [1939/2000] Training: GEN | Loss D: 0.67853, Loss G: 0.86614 | Accuracy: 0.63200 | fpR: 0.52800 | P: 0.60000 | R: 0.79200 | F1: 0.68227
# Epoch [1940/2000] Training: GEN | Loss D: 0.66523, Loss G: 0.82152 | Accuracy: 0.60000 | fpR: 0.64800 | P: 0.56684 | R: 0.84800 | F1: 0.67901
#
# Push Generator
#
# Epoch [1941/2000] Training: DISC | Loss D: 0.66821, Loss G: 0.97088 | Accuracy: 0.62000 | fpR: 0.48000 | P: 0.60000 | R: 0.72000 | F1: 0.65405
# Epoch [1942/2000] Training: DISC | Loss D: 0.56665, Loss G: 1.19315 | Accuracy: 0.68400 | fpR: 0.32000 | P: 0.68254 | R: 0.68800 | F1: 0.68476
# Epoch [1943/2000] Training: DISC | Loss D: 0.56169, Loss G: 1.27029 | Accuracy: 0.72400 | fpR: 0.20800 | P: 0.75926 | R: 0.65600 | F1: 0.70337
# Epoch [1944/2000] Training: DISC | Loss D: 0.54751, Loss G: 1.37265 | Accuracy: 0.73600 | fpR: 0.20800 | P: 0.76577 | R: 0.68000 | F1: 0.71984
# Epoch [1945/2000] Training: DISC | Loss D: 0.51449, Loss G: 1.27228 | Accuracy: 0.74800 | fpR: 0.24800 | P: 0.75000 | R: 0.74400 | F1: 0.74649
# Epoch [1946/2000] Training: DISC | Loss D: 0.50392, Loss G: 1.35879 | Accuracy: 0.84800 | fpR: 0.13600 | P: 0.85950 | R: 0.83200 | F1: 0.84503
# Epoch [1947/2000] Training: DISC | Loss D: 0.47383, Loss G: 1.31813 | Accuracy: 0.80400 | fpR: 0.12000 | P: 0.85849 | R: 0.72800 | F1: 0.78738
# Epoch [1948/2000] Training: DISC | Loss D: 0.45605, Loss G: 1.48679 | Accuracy: 0.80800 | fpR: 0.19200 | P: 0.80800 | R: 0.80800 | F1: 0.80750
# Epoch [1949/2000] Training: DISC | Loss D: 0.48936, Loss G: 1.57232 | Accuracy: 0.81200 | fpR: 0.14400 | P: 0.84211 | R: 0.76800 | F1: 0.80285
# Epoch [1950/2000] Training: DISC | Loss D: 0.47502, Loss G: 1.51612 | Accuracy: 0.82800 | fpR: 0.18400 | P: 0.82031 | R: 0.84000 | F1: 0.82954
# Epoch [1951/2000] Training: DISC | Loss D: 0.43860, Loss G: 1.47178 | Accuracy: 0.84400 | fpR: 0.10400 | P: 0.88393 | R: 0.79200 | F1: 0.83494
# Epoch [1952/2000] Training: DISC | Loss D: 0.44721, Loss G: 1.62342 | Accuracy: 0.82000 | fpR: 0.15200 | P: 0.83898 | R: 0.79200 | F1: 0.81432
# Epoch [1953/2000] Training: DISC | Loss D: 0.42091, Loss G: 1.40851 | Accuracy: 0.84800 | fpR: 0.14400 | P: 0.85366 | R: 0.84000 | F1: 0.84627
# Epoch [1954/2000] Training: DISC | Loss D: 0.37844, Loss G: 1.58298 | Accuracy: 0.84000 | fpR: 0.13600 | P: 0.85714 | R: 0.81600 | F1: 0.83557
# Epoch [1955/2000] Training: DISC | Loss D: 0.42923, Loss G: 1.56232 | Accuracy: 0.85600 | fpR: 0.11200 | P: 0.88034 | R: 0.82400 | F1: 0.85074
# Epoch [1956/2000] Training: DISC | Loss D: 0.37733, Loss G: 1.58057 | Accuracy: 0.85200 | fpR: 0.12000 | P: 0.87288 | R: 0.82400 | F1: 0.84724
# Epoch [1957/2000] Training: DISC | Loss D: 0.40016, Loss G: 1.48825 | Accuracy: 0.84400 | fpR: 0.13600 | P: 0.85833 | R: 0.82400 | F1: 0.84032
# Epoch [1958/2000] Training: DISC | Loss D: 0.38330, Loss G: 1.53562 | Accuracy: 0.84000 | fpR: 0.16800 | P: 0.83465 | R: 0.84800 | F1: 0.84077
# Epoch [1959/2000] Training: DISC | Loss D: 0.36884, Loss G: 1.54094 | Accuracy: 0.86400 | fpR: 0.10400 | P: 0.88889 | R: 0.83200 | F1: 0.85900
# Epoch [1960/2000] Training: DISC | Loss D: 0.36012, Loss G: 1.75576 | Accuracy: 0.86000 | fpR: 0.08800 | P: 0.90179 | R: 0.80800 | F1: 0.85182
# Epoch [1961/2000] Training: DISC | Loss D: 0.35126, Loss G: 1.89218 | Accuracy: 0.88400 | fpR: 0.06400 | P: 0.92857 | R: 0.83200 | F1: 0.87714
# Epoch [1962/2000] Training: DISC | Loss D: 0.32066, Loss G: 1.71439 | Accuracy: 0.86000 | fpR: 0.12800 | P: 0.86885 | R: 0.84800 | F1: 0.85780
# Epoch [1963/2000] Training: DISC | Loss D: 0.32453, Loss G: 1.91803 | Accuracy: 0.88800 | fpR: 0.09600 | P: 0.90083 | R: 0.87200 | F1: 0.88568
#
# Pull Generator
#
# Epoch [1964/2000] Training: GEN | Loss D: 0.38980, Loss G: 1.43976 | Accuracy: 0.88800 | fpR: 0.10400 | P: 0.89431 | R: 0.88000 | F1: 0.88660
# Epoch [1965/2000] Training: GEN | Loss D: 0.44151, Loss G: 1.26614 | Accuracy: 0.82000 | fpR: 0.23200 | P: 0.78986 | R: 0.87200 | F1: 0.82840
# Epoch [1966/2000] Training: GEN | Loss D: 0.49764, Loss G: 1.20651 | Accuracy: 0.83200 | fpR: 0.17600 | P: 0.82677 | R: 0.84000 | F1: 0.83283
# Epoch [1967/2000] Training: GEN | Loss D: 0.48301, Loss G: 1.10478 | Accuracy: 0.77600 | fpR: 0.35200 | P: 0.71975 | R: 0.90400 | F1: 0.80093
# Epoch [1968/2000] Training: GEN | Loss D: 0.51941, Loss G: 1.07918 | Accuracy: 0.78800 | fpR: 0.23200 | P: 0.77692 | R: 0.80800 | F1: 0.79166
# Epoch [1969/2000] Training: GEN | Loss D: 0.56892, Loss G: 1.04452 | Accuracy: 0.67200 | fpR: 0.45600 | P: 0.63694 | R: 0.80000 | F1: 0.70873
# Epoch [1970/2000] Training: GEN | Loss D: 0.63390, Loss G: 0.99324 | Accuracy: 0.68400 | fpR: 0.46400 | P: 0.64198 | R: 0.83200 | F1: 0.72425
# Epoch [1971/2000] Training: GEN | Loss D: 0.62518, Loss G: 0.90684 | Accuracy: 0.70400 | fpR: 0.47200 | P: 0.65089 | R: 0.88000 | F1: 0.74781
# Epoch [1972/2000] Training: GEN | Loss D: 0.61643, Loss G: 0.86043 | Accuracy: 0.66400 | fpR: 0.51200 | P: 0.62130 | R: 0.84000 | F1: 0.71380
# Epoch [1973/2000] Training: GEN | Loss D: 0.66544, Loss G: 0.79818 | Accuracy: 0.63600 | fpR: 0.57600 | P: 0.59551 | R: 0.84800 | F1: 0.69919
# Epoch [1974/2000] Training: GEN | Loss D: 0.63931, Loss G: 0.68290 | Accuracy: 0.63600 | fpR: 0.62400 | P: 0.58947 | R: 0.89600 | F1: 0.71063
#
# Push Generator
#
# Epoch [1975/2000] Training: DISC | Loss D: 0.62231, Loss G: 0.89439 | Accuracy: 0.65600 | fpR: 0.51200 | P: 0.61677 | R: 0.82400 | F1: 0.70499
# Epoch [1976/2000] Training: DISC | Loss D: 0.59489, Loss G: 1.03094 | Accuracy: 0.68400 | fpR: 0.35200 | P: 0.67164 | R: 0.72000 | F1: 0.69448
# Epoch [1977/2000] Training: DISC | Loss D: 0.52416, Loss G: 1.31286 | Accuracy: 0.78800 | fpR: 0.23200 | P: 0.77692 | R: 0.80800 | F1: 0.79166
# Epoch [1978/2000] Training: DISC | Loss D: 0.46518, Loss G: 1.31437 | Accuracy: 0.80000 | fpR: 0.18400 | P: 0.80992 | R: 0.78400 | F1: 0.79625
# Epoch [1979/2000] Training: DISC | Loss D: 0.48917, Loss G: 1.34931 | Accuracy: 0.74000 | fpR: 0.20000 | P: 0.77273 | R: 0.68000 | F1: 0.72291
# Epoch [1980/2000] Training: DISC | Loss D: 0.45686, Loss G: 1.28096 | Accuracy: 0.80800 | fpR: 0.14400 | P: 0.84071 | R: 0.76000 | F1: 0.79782
# Epoch [1981/2000] Training: DISC | Loss D: 0.49472, Loss G: 1.30386 | Accuracy: 0.77600 | fpR: 0.20000 | P: 0.78992 | R: 0.75200 | F1: 0.76999
# Epoch [1982/2000] Training: DISC | Loss D: 0.50475, Loss G: 1.45756 | Accuracy: 0.80000 | fpR: 0.19200 | P: 0.80488 | R: 0.79200 | F1: 0.79789
# Epoch [1983/2000] Training: DISC | Loss D: 0.46823, Loss G: 1.40980 | Accuracy: 0.79200 | fpR: 0.17600 | P: 0.81197 | R: 0.76000 | F1: 0.78462
# Epoch [1984/2000] Training: DISC | Loss D: 0.47449, Loss G: 1.42836 | Accuracy: 0.81200 | fpR: 0.20800 | P: 0.80000 | R: 0.83200 | F1: 0.81519
# Epoch [1985/2000] Training: DISC | Loss D: 0.44433, Loss G: 1.45582 | Accuracy: 0.80400 | fpR: 0.20800 | P: 0.79688 | R: 0.81600 | F1: 0.80582
# Epoch [1986/2000] Training: DISC | Loss D: 0.43268, Loss G: 1.49643 | Accuracy: 0.82400 | fpR: 0.15200 | P: 0.84034 | R: 0.80000 | F1: 0.81917
# Epoch [1987/2000] Training: DISC | Loss D: 0.43061, Loss G: 1.55305 | Accuracy: 0.82400 | fpR: 0.12000 | P: 0.86486 | R: 0.76800 | F1: 0.81306
# Epoch [1988/2000] Training: DISC | Loss D: 0.39143, Loss G: 1.52289 | Accuracy: 0.86400 | fpR: 0.13600 | P: 0.86400 | R: 0.86400 | F1: 0.86350
#
# Pull Generator
#
# Epoch [1989/2000] Training: GEN | Loss D: 0.40130, Loss G: 1.38037 | Accuracy: 0.78400 | fpR: 0.24000 | P: 0.77099 | R: 0.80800 | F1: 0.78856
# Epoch [1990/2000] Training: GEN | Loss D: 0.48230, Loss G: 1.18650 | Accuracy: 0.79600 | fpR: 0.24800 | P: 0.77206 | R: 0.84000 | F1: 0.80410
# Epoch [1991/2000] Training: GEN | Loss D: 0.53612, Loss G: 1.14966 | Accuracy: 0.75200 | fpR: 0.25600 | P: 0.74803 | R: 0.76000 | F1: 0.75347
# Epoch [1992/2000] Training: GEN | Loss D: 0.54336, Loss G: 1.17560 | Accuracy: 0.69200 | fpR: 0.36000 | P: 0.67391 | R: 0.74400 | F1: 0.70673
# Epoch [1993/2000] Training: GEN | Loss D: 0.55590, Loss G: 1.14399 | Accuracy: 0.74400 | fpR: 0.36000 | P: 0.70199 | R: 0.84800 | F1: 0.76762
# Epoch [1994/2000] Training: GEN | Loss D: 0.62609, Loss G: 0.95379 | Accuracy: 0.68000 | fpR: 0.44800 | P: 0.64331 | R: 0.80800 | F1: 0.71582
# Epoch [1995/2000] Training: GEN | Loss D: 0.64220, Loss G: 0.99089 | Accuracy: 0.68400 | fpR: 0.47200 | P: 0.64024 | R: 0.84000 | F1: 0.72615
# Epoch [1996/2000] Training: GEN | Loss D: 0.64053, Loss G: 0.91792 | Accuracy: 0.70000 | fpR: 0.41600 | P: 0.66234 | R: 0.81600 | F1: 0.73069
# Epoch [1997/2000] Training: GEN | Loss D: 0.76411, Loss G: 0.86057 | Accuracy: 0.64000 | fpR: 0.48800 | P: 0.61146 | R: 0.76800 | F1: 0.68036
# Epoch [1998/2000] Training: GEN | Loss D: 0.68888, Loss G: 0.85139 | Accuracy: 0.68400 | fpR: 0.47200 | P: 0.64024 | R: 0.84000 | F1: 0.72615
# Epoch [1999/2000] Training: GEN | Loss D: 0.73164, Loss G: 0.79458 | Accuracy: 0.57200 | fpR: 0.66400 | P: 0.54891 | R: 0.80800 | F1: 0.65324
#
# Push Generator
#
# Epoch [2000/2000] Training: DISC | Loss D: 0.69930, Loss G: 0.88188 | Accuracy: 0.61600 | fpR: 0.56800 | P: 0.58480 | R: 0.80000 | F1: 0.67519
#
#
# Training Session Finished
# Encountered 83 non-trivial training swaps
# Model Results Sucessfully Saved to "../model_outputs/Mod Test Gan.txt"
# Model Results Sucessfully Saved to "../model_outputs/Mod Test Gan.csv"
