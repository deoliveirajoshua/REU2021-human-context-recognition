# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
import random
import csv
from prettytable import PrettyTable
from pylab import *
from scipy.stats import wasserstein_distance
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cProfile
# %matplotlib inline

from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.utils.data import Dataset

dev = ""

if torch.cuda.is_available():  
  dev = "cuda:0" 
else:  
  dev = "cpu"  
device = torch.device(dev)

# %% [markdown]
# # Change directory

# %%
#Everyone's
os.chdir("../")

# %% [markdown]
# # Interpolating acceleration columns with average values

# %%
#replaces Nan values with average values
#df: data frame of data to use
def interpolation(df):
    col_to_avg = list(df.columns) #Start with keeping all the columns as columns to use an average interpolation on
    for k in range(len(list(df.columns))):
        if list(df.columns)[k].startswith(('discrete', 'label')): #Remove label and discrete columns from col_to_avg
            col_to_avg.remove(list(df.columns)[k])
    
    df_with_avg = df[col_to_avg].fillna(df[col_to_avg].mean()) #Interpolate nan columns for all continuous-valued columns with average
    
    col_to_zero = list(df.columns)
    for k in range(len(list(df.columns))):
        if not list(df.columns)[k].startswith(('discrete', 'label')): #Remove all columns except label and discrete
            col_to_zero.remove(list(df.columns)[k])
    
    df_with_zero = df[col_to_zero].fillna(0) #Interpolate nan values for label and discrete columns with 0
    
    return pd.concat([df_with_avg, df_with_zero], axis = 1)

# %% [markdown]
# # Load and scale data

# %%
##load and scale data
#returns scaled data (X) and labels (Y)
#file_name: string, file with data to be used
#label: string, activity to do
def start_data(file_name, label):
    #read csv into dataframe
    data = pd.read_csv(file_name)
    
    #seperate only acceleration data
    X = data.iloc[:,1:27]
    y = data[[label]]

    #seperate only "on" labels
    X = X[y[label] == 1]
    y = y[y[label] == 1]
    
    #interpolate averages per column
    X = interpolation(X).values
    y = interpolation(y).values
    
    #scale the data
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X = sc.fit_transform(X)
    
    return X, y

# %% [markdown]
# # Generator Functions

# %%
#defines each generator layer
#input and output dimensions needed
def generator_block(input_dim, output_dim):
    return nn.Sequential(
        nn.Linear(input_dim, output_dim),
        nn.Dropout(0.1),
        nn.BatchNorm1d(output_dim),
        nn.ReLU(inplace = True)
    )

#returns n_samples of z_dim (number of dimensions of latent space) noise
def get_noise(n_samples, z_dim):
    #torch.manual_seed(0)
    return torch.randn(n_samples, z_dim).to(device)

#defines generator class
class Generator(nn.Module):
    def __init__(self, z_dim = 10, feature_dim = 26, hidden_dim = 128):
        super(Generator, self).__init__()
        self.gen = nn.Sequential(
            generator_block(z_dim, int(hidden_dim/2)),
            generator_block(int(hidden_dim/2), int(hidden_dim/4)),
            generator_block(int(hidden_dim/4), 30),
            generator_block(30, 28),
            nn.Linear(28, feature_dim)
        )
    def forward(self, noise):
        return self.gen(noise)

##calculates generator loss
#gen: generator
#disc: discriminator
#criterion: loss function
#batch_size: batch size
#z_dim: number of dimensions in the latent space
def get_gen_loss(gen, disc, criterion, batch_size, z_dim):
    latent_vectors = get_noise(batch_size, z_dim)
    fake_features = gen(latent_vectors)
    disc.eval()
    pred = disc(fake_features)
    disc.train()
    gen_loss = criterion(pred, torch.ones_like(pred))
    return gen_loss

# %% [markdown]
# # Discriminator Functions

# %%
#defines each discriminator layer
def discriminator_block(input_dim, output_dim):
    return nn.Sequential(
        nn.Linear(input_dim, output_dim),
        nn.Dropout(0.1),
        nn.LeakyReLU(0.05)
    )

#defines discriminator class
class Discriminator(nn.Module):
    def __init__(self, feature_dim = 26, hidden_dim = 16):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            discriminator_block(feature_dim, hidden_dim),
            discriminator_block(hidden_dim, int(hidden_dim/2)),
            discriminator_block(int(hidden_dim/2), int(hidden_dim/4)),
            nn.Linear(int(hidden_dim/4), 1),
            nn.Sigmoid()                    
        )
    def forward(self, feature_vector):
        return self.disc(feature_vector)

##calculates discriminator loss
#gen: generator
#disc: discriminator
#real_features: real (not generated) data
#batch_size: batch size
#z_dim: number of dimensions of the latent space
def get_disc_loss(gen, disc, criterion, real_features, batch_size, z_dim):
    latent_vectors = get_noise(batch_size, z_dim)
    gen.eval()
    fake_features = gen(latent_vectors)
    gen.train()
    pred_fake = disc(fake_features.detach())
    loss_fake = criterion(pred_fake, torch.zeros_like(pred_fake))
                     
    pred_real = disc(real_features)
    loss_real = criterion(pred_real, torch.ones_like(pred_real))
    
    disc_loss = (loss_fake + loss_real) / 2
    return disc_loss

# %% [markdown]
# # Visualize Batches

# %%
##prints a plot of a generator batch
#gen: generator
#b_size: batch size
#epochs: current epoch (-1)
def visualize_gen_batch(gen, b_size, epochs = -1):
    #print(str(b_size))
    latent_vectors = get_noise(b_size, z_dim)
    #print(latent_vectors.shape)
    fake_features = gen(latent_vectors)
    #print(fake_features.shape)
    
    w_img = fake_features
    wmin = torch.min(w_img)
    wmax = torch.max(w_img)
    w_img = w_img.cpu()
    w_img = w_img.detach().numpy()
    c = plt.imshow(w_img, cmap ='Reds', vmin = wmin , vmax = wmax,
                        interpolation ='nearest', origin ='upper')
    plt.colorbar(c)
    plt.title('Generated Batch at Epoch ' + str(epochs), fontweight ="bold")
    plt.show()

##prints a plot of a batch of real data
#features: real data
def visualize_real_batch(features):
    w_img = features
    wmin = torch.min(w_img)
    wmax = torch.max(w_img)
    w_img = w_img.cpu()
    w_img = w_img.detach().numpy()
    c = plt.imshow(w_img, cmap ='Reds', vmin = wmin , vmax = wmax,
                        interpolation ='nearest', origin ='upper')
    plt.colorbar(c)
    plt.title('Real Batch of Data', fontweight ="bold")
    plt.show()

# %% [markdown]
# # Calculate Performance Statistics

# %%
##calculates performance statistics for each epoch of training
#gen: generator
#disc: discriminator
#b_size: batch size
#z_dim: number of dimensions of the latent space
##returns accuracy, precision, recall, fpR, and f1 score
def performance_stats(gen, disc, b_size, z_dim, batch = None):
    tp = 0 #true positive
    fp = 0 #false positive
    tn = 0 #true negative
    fn = 0 #false negative

    with torch.no_grad():
        y_hat_fake = torch.Tensor([0])
        y_hat_real = torch.Tensor([0])
        if batch is None:
            latent_vectors = get_noise(b_size, z_dim)
            gen.eval()
            fake_features = gen(latent_vectors)
            gen.train()
            disc.eval()
            y_hat_fake = torch.round(disc(fake_features))
            disc.train()
        else:
            latent_vectors = get_noise(b_size, z_dim)
            gen.eval()
            fake_features = gen(latent_vectors)
            gen.train()
            disc.eval()
            y_hat_fake = torch.round(disc(fake_features))
            y_hat_real = torch.round(disc(batch))
            disc.train()
         
        fpR = torch.mean(y_hat_fake)
        recall = torch.mean(y_hat_real)
        class_acc = ((len(y_hat_fake) - torch.sum(y_hat_fake)) + torch.sum(y_hat_real)) / (2*b_size)
        #print(f'Classification Accuracy: {class_acc:.2f}'
        #print(f'Recall: {recall:.2f}') #What percent of the true positives were identified
        return class_acc, recall, fpR

# %% [markdown]
# # Create Density Curves

# %%
#create and plot density curves for mean, x, y, z acceleration
#reals: real data
#fakes: generated data
def density_curves(reals, fakes):
    plt.figure(figsize = (15, 15))
    subplot(2, 2, 1)
    sns.kdeplot(fakes.cpu().numpy()[:,0], color = 'r', shade = True, label = 'Fake Distribution')
    sns.kdeplot(reals[:,0], color = 'b', shade = True, label = 'Real Distribution')
    plt.xlabel('Mean Acceleration')
    plt.ylabel('Density')
    plt.legend()
    #plt.show()

    subplot(2, 2, 2)
    sns.kdeplot(fakes.cpu().numpy()[:,18], color = 'r', shade = True, label = 'Fake Distribution')
    sns.kdeplot(reals[:,18], color = 'b', shade = True, label = 'Real Distribution')
    plt.xlabel('Mean X-Acceleration')
    plt.ylabel('Density')
    plt.legend()
    #plt.show()

    subplot(2, 2, 3)
    sns.kdeplot(fakes.cpu().numpy()[:,19], color = 'r', shade = True, label = 'Fake Distribution')
    sns.kdeplot(reals[:,19], color = 'b', shade = True, label = 'Real Distribution')
    plt.xlabel('Mean Y-Acceleration')
    plt.ylabel('Density')
    plt.legend()
    #plt.show()

    subplot(2, 2, 4)
    sns.kdeplot(fakes.cpu().numpy()[:,20], color = 'r', shade = True, label = 'Fake Distribution')
    sns.kdeplot(reals[:,20], color = 'b', shade = True, label = 'Real Distribution')
    plt.xlabel('Mean Z-Acceleration')
    plt.ylabel('Density')
    plt.legend()
    plt.show()

# %% [markdown]
# # Create fake samples

# %%
def get_fake_samples(gen, batch_size, z_dim):
    """
    Generates fake acceleration features given a batch size, latent vector dimension, and trained generator.
    
    """
    latent_vectors = get_noise(batch_size, z_dim) ### Retrieves a 2D tensor of noise
    gen.eval()
    fake_features = gen(latent_vectors)
    gen.train()
    return fake_features ### Returns a 2D tensor of fake features of size batch_size x z_dim

# %% [markdown]
# # Calculate Wassertein distance for each dimension

# %%
##calculate Waaserstein distances for each dimension
#gen: generator
#z_dim: number of dimensions of the latent space
#feature_dim: number ofd dimensions in the feature space
#sample: sample of data
def all_Wasserstein_dists(gen, z_dim, feature_dim, sample):
    latent_vectors = get_noise(len(sample), z_dim)
    gen.eval()
    fake_features = gen(latent_vectors).cpu().detach().numpy()
    gen.train()
    sample = sample.cpu().detach().numpy()
    return torch.tensor([wasserstein_distance(fake_features[:, k], sample[:, k]) for k in range(feature_dim)])

# %%
###initalize parameters that depend on training loop parameters
#X: acceleration data
#y: labels associated with X data (fake or real)
#z_dim: number of dimensions to the latent space
#disc_lr: discriminator learning rate
#gen_lr: generator learning rate
#DISCRIMINATOR: 1 to indicate if discriminator is training
#batch_size: batch size
#disc: initialized discrimiantor

def initialize_params(X, y, z_dim, disc_lr, gen_lr, DISCRIMINATOR, batch_size, disc):
    #initialize generator
    gen = Generator(z_dim).to(device)
    #indicate that discriminator is training
    to_train = DISCRIMINATOR
    #create training features
    train_features = torch.tensor(X)
    #create training labels
    train_labels = torch.tensor(y)
    #concatenate to create training data
    train_data = torch.utils.data.TensorDataset(train_features, train_labels)
    #create data loader for training data
    train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, shuffle = True)
    #initialize generator and discriminator optimizers
    opt_disc = optim.Adam(disc.parameters(), lr = disc_lr)
    opt_gen = optim.Adam(gen.parameters(), lr = gen_lr)
    
    return gen, to_train, train_features, train_labels, train_data, train_loader, opt_disc, opt_gen

# %% [markdown]
# # Saving the Model

# %%
# Change path and name of the Generator and Discriminator accordingly
def save_model(gen, disc, model_name):
    torch.save(gen.state_dict(), f"saved_models/{model_name}_gen.param")
    torch.save(disc.state_dict(), f"saved_models/{model_name}_disc.param")

# %% [markdown]
# # Visualizing Generation Quality

# %%
#creates and prints a plot of the generated vs real data
#data: data used
#gen: generator
#z_dim: number of dimensions of the latent space
def visualize_gen(data, gen, z_dim):
    #Number of datum to visualize
    sample_size = len(data)
    reals = data[0:sample_size, :]
    fakes = get_fake_samples(gen, sample_size, z_dim).detach()
    density_curves(reals, fakes)

# %% [markdown]
# # Plot Metrics

# %%
#plot metrics based on data (csv)
def plot_metrics(data, vanilla = True):
    if vanilla:
        sns.set(style = 'whitegrid', context = 'talk', palette = 'rainbow')
    
        plt.figure(figsize = (15, 15))
        subplot(2, 2, 1)
        sns.scatterplot(x = 'Epoch', y = 'FPR', data = data).set(xlim = (0, None))
        sns.despine()
        
        subplot(2, 2, 2)
        sns.scatterplot(x = 'Epoch', y = 'Recall', data = data).set(xlim = (0, None))
        sns.despine()
        
        subplot(2, 2, 3)
        sns.regplot(x = 'Epoch', y = 'Median Wasserstein', data = data, line_kws = {'color': 'orange'}).set(xlim = (0, None))
        sns.despine()
        
        subplot(2, 2, 4)
        sns.regplot(x = 'Epoch', y = 'Mean Wasserstein', data = data, line_kws = {'color': 'orange'}).set(xlim = (0, None))
        sns.despine()
        plt.show()
    else:
        sns.set(style = 'whitegrid', context = 'talk', palette = 'rainbow')
        plt.figure(figsize = (15, 8))
        
        subplot(1, 2, 1)
        sns.regplot(x = 'Epoch', y = 'Median Wasserstein', data = data, line_kws = {'color': 'orange'}).set(xlim = (0, None))
        sns.despine()
        
        subplot(1, 2, 2)
        sns.regplot(x = 'Epoch', y = 'Mean Wasserstein', data = data, line_kws = {'color': 'orange'}).set(xlim = (0, None))
        sns.despine()
        
        plt.show()

# %% [markdown]
# # Training Loop

# %%
######Training loop to train GAN

#Parameters to specifiy: 
    #X: starting accelerometer data
    #y: starting labels for X data (fake or real)
    
#Set parameters (do not change)
    #criterion: loss function (BCE)
    #dig: number of significant digits for printing (5)
    #feature_dim: Number of dimensions of output from generator (26)
    #GENERATOR: set generator to zero for training
    #DISCRIMINATOR: set discriminator to one for training
    #train_string: starting machine to train (DISC)
    #disc: initalize discriminator
    #rel_epochs: Epochs passed since last switch (constant training) (0)
    #rows: initialization of array to save data of each epoch to CSV file ([])
    #heading: array of column headings for table (["Epoch", "Machine Training", "Discriminator Loss", 
                    #"Generator Loss", "FPR", "Recall", "Median Wasserstein", "Mean Wasserstein"])
    #table: intialize a table as a pretty table to save epoch data
    #switch_count: number of switches in dynamic training (0)
    
#Set parameters (can change):
    #z_dim: number of dimensions of latent vector (100)
    #gen_lr: generator learning rate (.001)
    #disc_lr: discriminator learning rate (.001) (shoud be equal to gen_lr)
    #batch_size: batch size (75)
    #print_batches: Show model performance per batch (False)
    #n_epochs: number of epochs to train (100)
    #constant_train_flag: (False)
        #Set to true to train based on constant # of epochs per machine 
        #Set to false to train dynamically based on machine performance
        
    #Constant training approach:
        #disc_epochs: Number of consecutive epochs to train discriminator before epoch threshold (5)
        #gen_epochs: Number of consecutive epochs to train generator before epoch threshold (2)
        #epoch_threshold: Epoch number to change training epoch ratio (50)
        #disc_epochs_change: New number of consecutive epochs to train discriminator after epoch threshold is exceeded (1)
        #gen_epochs_change: New number of consecutive epochs to train generator after epoch threshold is exceeded (50)
    
    #Dynamic training approach:                        
        #static_threshold: Epoch number to change from static ratio to dynamic (18)
        #static_disc_epochs: Number of consecutive epochs to train discriminator before epoch threshold (4)
        #static_gen_epochs: Number of consecutive epochs to train generator before epoch threshold (2)
        #pull_threshold: Accuracy threshold for switching machine training when the generator is no longer competitive (0.4)
        #push_threshold: Accuracy threshold for switching machine training when the discriminator is no longer competitive (0.6)
        #recall_threshold: threshold for recall to switch machine training when discriminator is training well
        #switch_flag: indicates if we should switch our training machine (False)
        
def training_loop(X, y, criterion = nn.BCELoss(), gan_id = "Mod Test Gan", dig = 5, feature_dim = 26, 
                  GENERATOR = 0, DISCRIMINATOR = 1, train_string = "DISC", disc = Discriminator(), z_dim = 100, 
                  gen_lr =  0.001, disc_lr = 0.001, batch_size = 100, constant_train_flag = False, disc_epochs = 5,
                  gen_epochs = 2, epoch_threshold = 50, disc_epochs_change = 1, gen_epochs_change = 50, rel_epochs = 0,
                 static_threshold = 18, static_disc_epochs = 5, static_gen_epochs = 2, pull_threshold = 0.2,
                 push_threshold = 0.8, recall_threshold = 0.75, n_epochs = 1000, rows = [],
                 heading = ["Epoch", "Machine Training", "Discriminator Loss", "Generator Loss", "Accuracy", "FPR", "Recall", "Median Wasserstein", "Mean Wasserstein"],
                 table = PrettyTable(), switch_flag = False, switch_count = 0, last_real_features = []):
    
    disc.to(device)
    #returns generator, sets discriminator training, creates training tensor, loads data, and initializes optimizers
    gen, to_train, train_features, train_labels, train_data, train_loader, opt_disc, opt_gen = initialize_params(X, y, z_dim, disc_lr, gen_lr, DISCRIMINATOR, batch_size, disc)

    #set pretty table field names
    table.field_names = heading
    
    visualize_gen(X, gen, z_dim)

    gen_epochs = 0
    
    last_D_loss = -1.0
    last_G_loss = -1.0
    
    for epoch in range(n_epochs):  
        if constant_train_flag:
            if to_train == DISCRIMINATOR and rel_epochs >= disc_epochs:
                rel_epochs = 0
                to_train = GENERATOR
                train_string = "GEN"

            elif to_train == GENERATOR and rel_epochs >= gen_epochs:
                rel_epochs = 0
                to_train = DISCRIMINATOR
                train_string = "DISC"

            # Change epoch ratio after intial 'leveling out'
            if epoch == epoch_threshold:
                rel_epochs = 0
                to_train = GENERATOR
                train_string = "GENERATOR"

                old_ratio = gen_epochs / disc_epochs
                gen_epochs = gen_epochs_change
                disc_epochs = disc_epochs_change
                new_ratio = gen_epochs / disc_epochs
                print(f'\n\nTraining ratio of G/D switched from {old_ratio:.{dig}f} to {new_ratio:.{dig}f}\n\n')
        else:
            if epoch < static_threshold:
                if to_train == DISCRIMINATOR and rel_epochs >= static_disc_epochs:
                    rel_epochs = 0
                    to_train = GENERATOR
                    train_string = "GEN"

                elif to_train == GENERATOR and rel_epochs >= static_gen_epochs:
                    rel_epochs = 0
                    to_train = DISCRIMINATOR
                    train_string = "DISC"

            else:
                #to_train = DISCRIMINATOR
                #train_string = "DISC"
                if not switch_flag:
                    print("\nSwitching to Dynamic Training\n")
                    switch_flag = True
                    to_train = DISCRIMINATOR
                    train_string = "DISC"
                if to_train == DISCRIMINATOR and fpR <= pull_threshold and R >= recall_threshold:
                    to_train = GENERATOR
                    train_string = "GEN"
                    print("\nPull Generator\n")
                    switch_count += 1
                if to_train == GENERATOR and fpR >= push_threshold:
                    to_train = DISCRIMINATOR
                    train_string = "DISC"
                    print("\nPush Generator\n")
                    switch_count += 1
        print(f'Epoch[{epoch + 1}/{n_epochs}] Training: {train_string} ', end ='')
        for batch_idx, (real_features, _) in enumerate(train_loader):
            batch_size = len(real_features)
            #Send batch to GPU
            real_features = real_features.float().to(device)
            
            if to_train == DISCRIMINATOR:
                ### Training Discriminator
                #visualize_real_batch(real_features.float())
                opt_disc.zero_grad()
                disc_loss = get_disc_loss(gen, disc, criterion, real_features, batch_size, z_dim)
                disc_loss.backward(retain_graph = True)
                opt_disc.step()
                last_D_loss = disc_loss.item()
                
                if last_G_loss == -1.0:
                    last_G_loss = get_gen_loss(gen, disc, criterion, batch_size, z_dim)
            
            else:
                ### Training Generator
                opt_gen.zero_grad()
                gen_loss = get_gen_loss(gen, disc, criterion, batch_size, z_dim)
                gen_loss.backward()
                opt_gen.step()
                last_G_loss = gen_loss.item()
                
                if last_D_loss == -1.0:
                    last_D_loss = get_disc_loss(gen, disc, criterion, real_features, batch_size, z_dim)
                
                
        if batch_idx == (len(train_loader) - 1):
            acc, R, fpR = performance_stats(gen, disc, batch_size, z_dim, batch = real_features)
            w_dist = all_Wasserstein_dists(gen, z_dim, feature_dim, real_features)
            median_w_dist = torch.median(w_dist)
            mean_w_dist = torch.mean(w_dist)
            
            
        ### Currently doesn't print Median/Mean Wasserstein --> Change if needed
        print(f'| LossD: {last_D_loss:.{dig}f}, LossG: {last_G_loss:.{dig}f} | Acc: {acc:.{dig}f} | fpR: {fpR:.{dig}f} | R: {R:.{dig}f} | MedianW: {median_w_dist:.{dig}f} | MeanW: {mean_w_dist:.{dig}f}')
        row_to_add = [f"{epoch + 1}", train_string, f"{last_D_loss:.{dig}f}", f"{last_G_loss:.{dig}f}", f"{acc:.{dig}f}", f"{fpR:.{dig}f}", f"{R:.{dig}f}", f"{median_w_dist:.{dig}f}", f"{mean_w_dist:.{dig}f}"]
        table.add_row(row_to_add)
        rows.append(row_to_add)
        
        if to_train == GENERATOR:
            gen_epochs += 1
            
        rel_epochs += 1
    print("\n\nTraining Session Finished")
    print(f"Encountered {switch_count} non-trivial training swaps")
    percent = gen_epochs / n_epochs
    print(f"Trained Generator {gen_epochs} out of {n_epochs} ({percent:.3f})")
    f = open("model_outputs/" + gan_id + ".txt", "w")
    f.write(table.get_string())
    f.close()
    print("Model Results Sucessfully Saved to \"model_outputs/" + gan_id + ".txt\"")

    with open("model_outputs/" + gan_id + ".csv", "w") as csvfile: 
        # creating a csv writer object 
        csvwriter = csv.writer(csvfile) 
        # writing the fields 
        csvwriter.writerow(heading)
        # writing the data rows 
        csvwriter.writerows(rows)
    print("Model Results Sucessfully Saved to \"model_outputs/" + gan_id + ".csv\"")
    save_model(gen, disc, gan_id)
    print("Generator's Trained Parameters Sucessfully Saved to \"saved_models/" + gan_id + "_gen.param\"")
    print("Discriminators's Trained Parameters Sucessfully Saved to \"saved_models/" + gan_id + "_disc.param\"")
    model_output = pd.read_csv("model_outputs/" + gan_id + ".csv")
    visualize_gen(X, gen, z_dim)
    
    return model_output

# %% [markdown]
# # Running training

# %%
#X, y = start_data("aggregated_data/aggregated_data.csv", "label:SITTING")
X, y = start_data("raw_data/0A986513-7828-4D53-AA1F-E02D6DF9561B.features_labels.csv", "label:SITTING")
model_output = training_loop(X,y, gan_id="profile_test", batch_size = len(X), gen_lr=.001, disc_lr =.001, n_epochs=100, dig=4, constant_train_flag=True, disc_epochs = 5, gen_epochs = 5)
plot_metrics(model_output, True)
# Out:
# Epoch[1/100] Training: DISC | LossD: 0.6197, LossG: 0.5681 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5289 | MeanW: 0.5432
# Epoch[2/100] Training: DISC | LossD: 0.6183, LossG: 0.5681 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5290 | MeanW: 0.5433
# Epoch[3/100] Training: DISC | LossD: 0.6148, LossG: 0.5681 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5286 | MeanW: 0.5432
# Epoch[4/100] Training: DISC | LossD: 0.6121, LossG: 0.5681 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5287 | MeanW: 0.5432
# Epoch[5/100] Training: DISC | LossD: 0.6108, LossG: 0.5681 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5288 | MeanW: 0.5432
# Epoch[6/100] Training: GEN | LossD: 0.6108, LossG: 0.5773 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5235 | MeanW: 0.5421
# Epoch[7/100] Training: DISC | LossD: 0.6107, LossG: 0.5773 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5229 | MeanW: 0.5421
# Epoch[8/100] Training: DISC | LossD: 0.6069, LossG: 0.5773 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5233 | MeanW: 0.5421
# Epoch[9/100] Training: DISC | LossD: 0.6064, LossG: 0.5773 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5231 | MeanW: 0.5421
# Epoch[10/100] Training: DISC | LossD: 0.6018, LossG: 0.5773 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5225 | MeanW: 0.5421
# Epoch[11/100] Training: DISC | LossD: 0.5995, LossG: 0.5773 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5226 | MeanW: 0.5422
# Epoch[12/100] Training: GEN | LossD: 0.5995, LossG: 0.5799 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5180 | MeanW: 0.5403
# Epoch[13/100] Training: GEN | LossD: 0.5995, LossG: 0.5725 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5127 | MeanW: 0.5382
# Epoch[14/100] Training: GEN | LossD: 0.5995, LossG: 0.5616 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5104 | MeanW: 0.5355
# Epoch[15/100] Training: GEN | LossD: 0.5995, LossG: 0.5503 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5103 | MeanW: 0.5327
# Epoch[16/100] Training: GEN | LossD: 0.5995, LossG: 0.5416 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5115 | MeanW: 0.5298
# Epoch[17/100] Training: GEN | LossD: 0.5995, LossG: 0.5332 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5130 | MeanW: 0.5256
# Epoch[18/100] Training: GEN | LossD: 0.5995, LossG: 0.5240 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5169 | MeanW: 0.5219
# Epoch[19/100] Training: GEN | LossD: 0.5995, LossG: 0.5153 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5219 | MeanW: 0.5178
# Epoch[20/100] Training: GEN | LossD: 0.5995, LossG: 0.5065 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5226 | MeanW: 0.5126
# Epoch[21/100] Training: GEN | LossD: 0.5995, LossG: 0.5000 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5127 | MeanW: 0.5078
# Epoch[22/100] Training: GEN | LossD: 0.5995, LossG: 0.4906 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5003 | MeanW: 0.5017
# Epoch[23/100] Training: GEN | LossD: 0.5995, LossG: 0.4837 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4976 | MeanW: 0.4956
# Epoch[24/100] Training: GEN | LossD: 0.5995, LossG: 0.4778 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5026 | MeanW: 0.4921
# Epoch[25/100] Training: GEN | LossD: 0.5995, LossG: 0.4709 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5013 | MeanW: 0.4838
# Epoch[26/100] Training: GEN | LossD: 0.5995, LossG: 0.4644 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4887 | MeanW: 0.4791
# Epoch[27/100] Training: GEN | LossD: 0.5995, LossG: 0.4586 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4788 | MeanW: 0.4737
# Epoch[28/100] Training: GEN | LossD: 0.5995, LossG: 0.4536 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4694 | MeanW: 0.4701
# Epoch[29/100] Training: GEN | LossD: 0.5995, LossG: 0.4486 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4597 | MeanW: 0.4656
# Epoch[30/100] Training: GEN | LossD: 0.5995, LossG: 0.4436 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4509 | MeanW: 0.4599
# Epoch[31/100] Training: GEN | LossD: 0.5995, LossG: 0.4408 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4500 | MeanW: 0.4577
# Epoch[32/100] Training: GEN | LossD: 0.5995, LossG: 0.4366 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4401 | MeanW: 0.4582
# Epoch[33/100] Training: GEN | LossD: 0.5995, LossG: 0.4314 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4352 | MeanW: 0.4561
# Epoch[34/100] Training: GEN | LossD: 0.5995, LossG: 0.4270 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4356 | MeanW: 0.4533
# Epoch[35/100] Training: GEN | LossD: 0.5995, LossG: 0.4234 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4282 | MeanW: 0.4533
# Epoch[36/100] Training: GEN | LossD: 0.5995, LossG: 0.4206 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4169 | MeanW: 0.4576
# Epoch[37/100] Training: GEN | LossD: 0.5995, LossG: 0.4172 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4120 | MeanW: 0.4560
# Epoch[38/100] Training: GEN | LossD: 0.5995, LossG: 0.4140 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4245 | MeanW: 0.4569
# Epoch[39/100] Training: GEN | LossD: 0.5995, LossG: 0.4104 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4398 | MeanW: 0.4595
# Epoch[40/100] Training: GEN | LossD: 0.5995, LossG: 0.4068 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4411 | MeanW: 0.4596
# Epoch[41/100] Training: GEN | LossD: 0.5995, LossG: 0.4046 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4496 | MeanW: 0.4636
# Epoch[42/100] Training: GEN | LossD: 0.5995, LossG: 0.4006 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4568 | MeanW: 0.4644
# Epoch[43/100] Training: GEN | LossD: 0.5995, LossG: 0.3977 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4574 | MeanW: 0.4640
# Epoch[44/100] Training: GEN | LossD: 0.5995, LossG: 0.3949 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4620 | MeanW: 0.4653
# Epoch[45/100] Training: GEN | LossD: 0.5995, LossG: 0.3907 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4831 | MeanW: 0.4747
# Epoch[46/100] Training: GEN | LossD: 0.5995, LossG: 0.3887 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4843 | MeanW: 0.4762
# Epoch[47/100] Training: GEN | LossD: 0.5995, LossG: 0.3853 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4933 | MeanW: 0.4779
# Epoch[48/100] Training: GEN | LossD: 0.5995, LossG: 0.3836 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4961 | MeanW: 0.4813
# Epoch[49/100] Training: GEN | LossD: 0.5995, LossG: 0.3800 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5128 | MeanW: 0.4909
# Epoch[50/100] Training: GEN | LossD: 0.5995, LossG: 0.3779 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.4989 | MeanW: 0.4878
#
#
# Training ratio of G/D switched from 8.0000 to 50.0000
#
#
# Epoch[51/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3747 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5149 | MeanW: 0.4958
# Epoch[52/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3724 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5302 | MeanW: 0.5025
# Epoch[53/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3689 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5207 | MeanW: 0.5028
# Epoch[54/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3669 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5216 | MeanW: 0.5110
# Epoch[55/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3640 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5102 | MeanW: 0.5080
# Epoch[56/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3606 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5274 | MeanW: 0.5200
# Epoch[57/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3573 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5382 | MeanW: 0.5271
# Epoch[58/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3558 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5382 | MeanW: 0.5221
# Epoch[59/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3516 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5443 | MeanW: 0.5277
# Epoch[60/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3503 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5443 | MeanW: 0.5497
# Epoch[61/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3466 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5317 | MeanW: 0.5499
# Epoch[62/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3433 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5181 | MeanW: 0.5467
# Epoch[63/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3409 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5392 | MeanW: 0.5606
# Epoch[64/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3392 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5306 | MeanW: 0.5671
# Epoch[65/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3359 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5582 | MeanW: 0.5791
# Epoch[66/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3321 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5450 | MeanW: 0.5782
# Epoch[67/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3303 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5566 | MeanW: 0.5799
# Epoch[68/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3260 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5640 | MeanW: 0.5929
# Epoch[69/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3249 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5680 | MeanW: 0.5991
# Epoch[70/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3201 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5689 | MeanW: 0.5993
# Epoch[71/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3200 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5951 | MeanW: 0.6192
# Epoch[72/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3148 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.5939 | MeanW: 0.6170
# Epoch[73/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3119 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6152 | MeanW: 0.6251
# Epoch[74/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3087 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6363 | MeanW: 0.6447
# Epoch[75/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3083 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6418 | MeanW: 0.6395
# Epoch[76/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3040 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6507 | MeanW: 0.6473
# Epoch[77/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.3028 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6585 | MeanW: 0.6485
# Epoch[78/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2997 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6631 | MeanW: 0.6708
# Epoch[79/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2964 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6762 | MeanW: 0.6695
# Epoch[80/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2935 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6706 | MeanW: 0.6706
# Epoch[81/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2904 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6758 | MeanW: 0.6859
# Epoch[82/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2872 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6766 | MeanW: 0.6938
# Epoch[83/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2846 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6731 | MeanW: 0.7004
# Epoch[84/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2814 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6803 | MeanW: 0.7087
# Epoch[85/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2778 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.6776 | MeanW: 0.7100
# Epoch[86/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2759 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.7208 | MeanW: 0.7307
# Epoch[87/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2742 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.7131 | MeanW: 0.7303
# Epoch[88/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2714 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.7502 | MeanW: 0.7505
# Epoch[89/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2690 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.7600 | MeanW: 0.7604
# Epoch[90/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2658 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.7701 | MeanW: 0.7632
# Epoch[91/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2615 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.8041 | MeanW: 0.7841
# Epoch[92/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2583 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.8103 | MeanW: 0.7877
# Epoch[93/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2565 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.8331 | MeanW: 0.8168
# Epoch[94/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2537 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.8393 | MeanW: 0.8204
# Epoch[95/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2504 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.8478 | MeanW: 0.8292
# Epoch[96/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2482 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.8560 | MeanW: 0.8385
# Epoch[97/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2450 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.8743 | MeanW: 0.8456
# Epoch[98/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2436 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.9160 | MeanW: 0.8811
# Epoch[99/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2398 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.9215 | MeanW: 0.8953
# Epoch[100/100] Training: GENERATOR | LossD: 0.5995, LossG: 0.2365 | Acc: 0.5000 | fpR: 1.0000 | R: 1.0000 | MedianW: 0.9350 | MeanW: 0.9040
#
#
# Training Session Finished
# Encountered 0 non-trivial training swaps
# Trained Generator 100 out of 100 (1.000)
# Model Results Sucessfully Saved to "model_outputs/profile_test.txt"
# Model Results Sucessfully Saved to "model_outputs/profile_test.csv"
# Generator's Trained Parameters Sucessfully Saved to "saved_models/profile_test_gen.param"
# Discriminators's Trained Parameters Sucessfully Saved to "saved_models/profile_test_disc.param"
#          3767021 function calls (3714172 primitive calls) in 7.563 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       104    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(all)
#      4182    0.002    0.000    0.024    0.000 <__array_function__ internals>:2(amax)
#      4162    0.002    0.000    0.026    0.000 <__array_function__ internals>:2(amin)
#       560    0.000    0.000    0.006    0.000 <__array_function__ internals>:2(any)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(append)
#      5200    0.005    0.000    0.645    0.000 <__array_function__ internals>:2(argsort)
#      1204    0.001    0.000    0.008    0.000 <__array_function__ internals>:2(around)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(array_equal)
#       112    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_1d)
#        96    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_2d)
#        28    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_3d)
#        16    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(average)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(bincount)
#       186    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(broadcast_arrays)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(broadcast_to)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(can_cast)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(cholesky)
#       364    0.000    0.000    0.013    0.000 <__array_function__ internals>:2(clip)
#       210    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(column_stack)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(common_type)
#      2987    0.003    0.000    0.018    0.000 <__array_function__ internals>:2(concatenate)
#        32    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#        16    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(cov)
#       224    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(cumsum)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(delete)
#        32    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diag)
#        32    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diagonal)
#      2664    0.003    0.000    0.048    0.000 <__array_function__ internals>:2(diff)
#      1708    0.001    0.000    0.006    0.000 <__array_function__ internals>:2(dot)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#        64    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(hstack)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(in1d)
#        28    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(intersect1d)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(iscomplexobj)
#         8    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(isin)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(linspace)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(min_scalar_type)
#       752    0.001    0.000    0.003    0.000 <__array_function__ internals>:2(ndim)
#       372    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(nonzero)
#        32    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(prod)
#       352    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(ptp)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ravel)
#       405    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(reshape)
#        40    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#      1204    0.001    0.000    0.011    0.000 <__array_function__ internals>:2(round_)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(sort)
#      2632    0.003    0.000    0.046    0.000 <__array_function__ internals>:2(sum)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(tile)
#        56    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(unique)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(unravel_index)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(vstack)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(zeros_like)
#       277    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#       172    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:389(parent)
#         1    0.000    0.000    0.005    0.005 <ipython-input-10-9e17b2b397dd>:1(get_fake_samples)
#         1    0.000    0.000    0.018    0.018 <ipython-input-12-ad815b5aad23>:11(initialize_params)
#         1    0.000    0.000    0.006    0.006 <ipython-input-13-4352b7159e58>:2(save_model)
#         1    0.000    0.000    1.041    1.041 <ipython-input-14-37cd276fa1e2>:5(visualize_gen)
#       302    0.003    0.000    0.605    0.002 <ipython-input-5-72a59d00cfae>:12(get_noise)
#         1    0.000    0.000    0.002    0.002 <ipython-input-5-72a59d00cfae>:18(__init__)
#       302    0.001    0.000    0.319    0.001 <ipython-input-5-72a59d00cfae>:27(forward)
#         4    0.000    0.000    0.002    0.000 <ipython-input-5-72a59d00cfae>:3(generator_block)
#        91    0.001    0.000    0.390    0.004 <ipython-input-5-72a59d00cfae>:36(get_gen_loss)
#       100    0.007    0.000    2.194    0.022 <ipython-input-56-82116bfce3c9>:12(<listcomp>)
#       100    0.006    0.000    2.572    0.026 <ipython-input-56-82116bfce3c9>:6(all_Wasserstein_dists)
#       311    0.001    0.000    0.142    0.000 <ipython-input-6-33bb9b2a93a3>:20(forward)
#         1    0.016    0.016    7.563    7.563 <ipython-input-60-920a110138e4>:49(training_loop)
#        10    0.001    0.000    0.048    0.005 <ipython-input-62-3972b0287fb0>:29(get_disc_loss)
#       100    0.009    0.000    0.453    0.005 <ipython-input-8-cdc20bb36a28>:7(performance_stats)
#         1    0.000    0.000    1.036    1.036 <ipython-input-9-871eabdbd921>:4(density_curves)
#       566    0.000    0.000    0.001    0.000 <string>:1(__new__)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.040    0.040 Image.py:2095(save)
#         2    0.000    0.000    0.000    0.000 Image.py:2588(_check_size)
#         1    0.000    0.000    0.000    0.000 Image.py:2606(new)
#         1    0.000    0.000    0.000    0.000 Image.py:2683(frombuffer)
#         1    0.000    0.000    0.000    0.000 Image.py:336(preinit)
#         1    0.000    0.000    0.000    0.000 Image.py:431(_getencoder)
#         3    0.000    0.000    0.000    0.000 Image.py:519(__init__)
#         4    0.000    0.000    0.000    0.000 Image.py:551(size)
#         2    0.000    0.000    0.000    0.000 Image.py:555(_new)
#         1    0.000    0.000    0.001    0.001 Image.py:611(_copy)
#         1    0.000    0.000    0.001    0.001 Image.py:617(_ensure_mutable)
#         2    0.000    0.000    0.000    0.000 Image.py:804(load)
#         1    0.000    0.000    0.039    0.039 ImageFile.py:478(_save)
#         1    0.000    0.000    0.000    0.000 ImageFile.py:79(_tilesort)
#         6    0.000    0.000    0.000    0.000 PngImagePlugin.py:1011(putchunk)
#         1    0.000    0.000    0.000    0.000 PngImagePlugin.py:1025(__init__)
#         2    0.000    0.000    0.000    0.000 PngImagePlugin.py:1029(write)
#         1    0.000    0.000    0.039    0.039 PngImagePlugin.py:1178(_save)
#        12    0.000    0.000    0.000    0.000 PngImagePlugin.py:137(_crc32)
#         1    0.000    0.000    0.000    0.000 PngImagePlugin.py:265(__init__)
#         1    0.000    0.000    0.000    0.000 PngImagePlugin.py:268(add)
#         1    0.000    0.000    0.000    0.000 PngImagePlugin.py:311(add_text)
#      2141    0.002    0.000    0.002    0.000 _VF.py:25(__getattr__)
#        34    0.000    0.000    0.000    0.000 __future__.py:18(get_overwrite_module_params_on_conversion)
#        21    0.000    0.000    0.000    0.000 __init__.py:100(__hash__)
#        38    0.000    0.000    0.000    0.000 __init__.py:107(is_initialized)
#         1    0.000    0.000    0.000    0.000 __init__.py:1189(get_backend)
#         1    0.000    0.000    0.000    0.000 __init__.py:1207(is_interactive)
#        16    0.000    0.000    0.000    0.000 __init__.py:1242(contiguous_regions)
#       454    0.001    0.000    0.001    0.000 __init__.py:1268(is_math_text)
#         4    0.000    0.000    0.000    0.000 __init__.py:1280(getLogger)
#      1064    0.001    0.000    0.003    0.000 __init__.py:1281(_to_unmasked_float_array)
#        38    0.000    0.000    0.000    0.000 __init__.py:144(_lazy_init)
#        16    0.000    0.000    0.017    0.001 __init__.py:1444(inner)
#        82    0.000    0.000    0.000    0.000 __init__.py:158(__init__)
#       170    0.000    0.000    0.000    0.000 __init__.py:1610(<lambda>)
#       152    0.000    0.000    0.000    0.000 __init__.py:1652(safe_first_element)
#        40    0.000    0.000    0.000    0.000 __init__.py:1674(sanitize_sequence)
#        16    0.000    0.000    0.000    0.000 __init__.py:168(connect)
#       670    0.004    0.000    0.007    0.000 __init__.py:1682(normalize_kwargs)
#       670    0.002    0.000    0.002    0.000 __init__.py:1742(<dictcomp>)
#       670    0.000    0.000    0.000    0.000 __init__.py:1756(<listcomp>)
#       670    0.000    0.000    0.000    0.000 __init__.py:1761(<listcomp>)
#         4    0.000    0.000    0.001    0.000 __init__.py:183(dumps)
#       236    0.000    0.000    0.000    0.000 __init__.py:1830(_str_equal)
#        80    0.000    0.000    0.000    0.000 __init__.py:1841(_str_lower_equal)
#         2    0.000    0.000    0.000    0.000 __init__.py:186(_remove_proxy)
#        28    0.000    0.000    0.000    0.000 __init__.py:1874(method)
#         4    0.000    0.000    0.000    0.000 __init__.py:19(get_projection_class)
#         1    0.000    0.000    0.000    0.000 __init__.py:199(disconnect)
#         4    0.000    0.000    0.000    0.000 __init__.py:2014(getLogger)
#      4792    0.007    0.000    0.012    0.000 __init__.py:2045(_setattr_cm)
#         4    0.000    0.000    0.000    0.000 __init__.py:2112(__init__)
#         8    0.000    0.000    0.000    0.000 __init__.py:2128(discard)
#        31    0.000    0.000    0.000    0.000 __init__.py:213(process)
#         4    0.000    0.000    0.000    0.000 __init__.py:214(_acquireLock)
#        38    0.000    0.000    0.000    0.000 __init__.py:216(__init__)
#        38    0.000    0.000    0.000    0.000 __init__.py:220(__enter__)
#       815    0.003    0.000    0.005    0.000 __init__.py:2219(_check_isinstance)
#         4    0.000    0.000    0.000    0.000 __init__.py:223(_releaseLock)
#      1630    0.000    0.000    0.000    0.000 __init__.py:2234(<genexpr>)
#       815    0.001    0.000    0.001    0.000 __init__.py:2236(type_name)
#      5583    0.004    0.000    0.004    0.000 __init__.py:2254(_check_in_list)
#       406    0.001    0.000    0.002    0.000 __init__.py:2271(_check_shape)
#        38    0.000    0.000    0.000    0.000 __init__.py:228(__exit__)
#      1218    0.000    0.000    0.000    0.000 __init__.py:2291(<genexpr>)
#       904    0.000    0.000    0.000    0.000 __init__.py:271(is_storage)
#       100    0.001    0.000    0.003    0.000 __init__.py:28(_make_grads)
#      1208    0.001    0.000    0.001    0.000 __init__.py:31(__get__)
#         4    0.000    0.000    0.000    0.000 __init__.py:44(get_projection_class)
#        38    0.000    0.000    0.003    0.000 __init__.py:491(type)
#        66    0.000    0.000    0.001    0.000 __init__.py:536(__setitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:552(__init__)
#        14    0.000    0.000    0.000    0.000 __init__.py:580(push)
#       100    0.000    0.000    0.000    0.000 __init__.py:60(_tensor_or_tensors_to_tuple)
#         6    0.000    0.000    0.000    0.000 __init__.py:605(clear)
#         4    0.000    0.000    0.000    0.000 __init__.py:610(bubble)
#       100    0.001    0.000    0.172    0.002 __init__.py:68(backward)
#     22075    0.012    0.000    0.015    0.000 __init__.py:686(__getitem__)
#         2    0.000    0.000    0.000    0.000 __init__.py:798(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:799(<dictcomp>)
#      3348    0.002    0.000    0.003    0.000 __init__.py:804(clean)
#      3348    0.001    0.000    0.001    0.000 __init__.py:807(<listcomp>)
#      3340    0.005    0.000    0.010    0.000 __init__.py:853(get_siblings)
#      3340    0.001    0.000    0.001    0.000 __init__.py:857(<listcomp>)
#        10    0.000    0.000    0.000    0.000 __init__.py:91(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:94(__call__)
# 13304/13200    0.006    0.000    0.063    0.000 _asarray.py:14(asarray)
#        11    0.000    0.000    0.000    0.000 _asarray.py:221(require)
#        11    0.000    0.000    0.000    0.000 _asarray.py:298(<setcomp>)
#      6768    0.003    0.000    0.011    0.000 _asarray.py:86(asanyarray)
#         8    0.000    0.000    0.000    0.000 _axes.py:196(get_xlabel)
#        12    0.000    0.000    0.000    0.000 _axes.py:203(set_xlabel)
#         8    0.000    0.000    0.000    0.000 _axes.py:249(get_ylabel)
#         8    0.000    0.000    0.000    0.000 _axes.py:256(set_ylabel)
#         4    0.000    0.000    0.007    0.002 _axes.py:316(legend)
#        16    0.001    0.000    0.016    0.001 _axes.py:5097(_fill_between_x_or_y)
#        40    0.000    0.000    0.000    0.000 _axes.py:5192(<genexpr>)
#        16    0.000    0.000    0.016    0.001 _axes.py:5299(fill_between)
#         4    0.000    0.000    0.071    0.018 _base.py:1038(cla)
#         4    0.000    0.000    0.000    0.000 _base.py:1195(_set_title_offset_trans)
#        20    0.000    0.000    0.000    0.000 _base.py:1281(get_aspect)
#         4    0.000    0.000    0.000    0.000 _base.py:1432(set_box_aspect)
#        20    0.000    0.000    0.001    0.000 _base.py:1566(apply_aspect)
#         8    0.000    0.000    0.000    0.000 _base.py:185(__init__)
#        16    0.000    0.000    0.003    0.000 _base.py:1917(add_collection)
#         8    0.000    0.000    0.000    0.000 _base.py:198(set_prop_cycle)
#        16    0.000    0.000    0.001    0.000 _base.py:2123(update_datalim)
#        56    0.000    0.000    0.001    0.000 _base.py:2161(_process_unit_info)
#       112    0.000    0.000    0.001    0.000 _base.py:2164(_process_single_axis)
#         8    0.000    0.000    0.000    0.000 _base.py:2249(use_sticky_edges)
#         8    0.000    0.000    0.007    0.001 _base.py:2446(autoscale_view)
#         8    0.000    0.000    0.000    0.000 _base.py:2496(<listcomp>)
#         8    0.000    0.000    0.000    0.000 _base.py:2502(<listcomp>)
#        16    0.000    0.000    0.006    0.000 _base.py:2512(handle_single_axis)
#        16    0.000    0.000    0.000    0.000 _base.py:2519(<listcomp>)
#        16    0.000    0.000    0.000    0.000 _base.py:2521(<listcomp>)
#        16    0.000    0.000    0.000    0.000 _base.py:2525(<listcomp>)
#        16    0.000    0.000    0.000    0.000 _base.py:2528(<listcomp>)
#       120    0.000    0.000    0.000    0.000 _base.py:2586(_get_axis_list)
#        16    0.001    0.000    0.229    0.014 _base.py:2607(_update_title_position)
#        64    0.000    0.000    0.000    0.000 _base.py:2658(<genexpr>)
#         8    0.000    0.000    0.406    0.051 _base.py:2665(draw)
#         4    0.000    0.000    0.000    0.000 _base.py:2815(set_axisbelow)
#         8    0.000    0.000    0.042    0.005 _base.py:2851(grid)
#         8    0.000    0.000    0.011    0.001 _base.py:3013(tick_params)
#         4    0.000    0.000    0.000    0.000 _base.py:3101(set_axis_on)
#         8    0.000    0.000    0.000    0.000 _base.py:3126(get_xbound)
#         8    0.000    0.000    0.001    0.000 _base.py:3142(set_xbound)
#         8    0.000    0.000    0.000    0.000 _base.py:3174(get_xlim)
#        48    0.000    0.000    0.001    0.000 _base.py:3197(_validate_converted_limits)
#        12    0.000    0.000    0.001    0.000 _base.py:3214(set_xlim)
#         8    0.000    0.000    0.000    0.000 _base.py:3415(get_ybound)
#         8    0.000    0.000    0.001    0.000 _base.py:3431(set_ybound)
#         8    0.000    0.000    0.000    0.000 _base.py:3463(get_ylim)
#        12    0.000    0.000    0.001    0.000 _base.py:3486(set_ylim)
#         4    0.000    0.000    0.000    0.000 _base.py:3752(set_navigate)
#         4    0.000    0.000    0.000    0.000 _base.py:3768(set_navigate_mode)
#        44    0.000    0.000    0.000    0.000 _base.py:4036(get_children)
#        12    0.000    0.000    0.000    0.000 _base.py:4068(get_default_bbox_extra_artists)
#        12    0.000    0.000    0.000    0.000 _base.py:4092(<listcomp>)
#         8    0.001    0.000    0.187    0.023 _base.py:4095(get_tightbbox)
#         8    0.000    0.000    0.000    0.000 _base.py:4206(<listcomp>)
#         4    0.000    0.000    0.097    0.024 _base.py:434(__init__)
#         8    0.000    0.000    0.000    0.000 _base.py:593(get_window_extent)
#         4    0.000    0.000    0.010    0.003 _base.py:611(_init_axis)
#     68/20    0.000    0.000    0.080    0.004 _base.py:62(wrapper)
#         4    0.000    0.000    0.001    0.000 _base.py:621(set_figure)
# 1540/1508    0.003    0.000    0.022    0.000 _base.py:635(_unstale_viewLim)
#      3080    0.001    0.000    0.001    0.000 _base.py:638(<genexpr>)
#      3080    0.001    0.000    0.001    0.000 _base.py:640(<genexpr>)
# 1532/1500    0.001    0.000    0.023    0.000 _base.py:649(viewLim)
#        16    0.000    0.000    0.000    0.000 _base.py:656(_request_autoscale_view)
#         4    0.000    0.000    0.000    0.000 _base.py:664(_set_lim_and_transforms)
#   314/170    0.000    0.000    0.001    0.000 _base.py:700(get_xaxis_transform)
#        34    0.000    0.000    0.001    0.000 _base.py:724(get_xaxis_text1_transform)
#        34    0.000    0.000    0.001    0.000 _base.py:750(get_xaxis_text2_transform)
#   332/180    0.000    0.000    0.001    0.000 _base.py:776(get_yaxis_transform)
#        36    0.000    0.000    0.001    0.000 _base.py:800(get_yaxis_text1_transform)
#        36    0.000    0.000    0.001    0.000 _base.py:826(get_yaxis_text2_transform)
#         8    0.000    0.000    0.000    0.000 _base.py:852(_update_transScale)
#     24/20    0.000    0.000    0.000    0.000 _base.py:862(get_position)
#        20    0.000    0.000    0.001    0.000 _base.py:911(_set_position)
#         8    0.000    0.000    0.000    0.000 _base.py:938(set_axes_locator)
#        32    0.000    0.000    0.000    0.000 _base.py:949(get_axes_locator)
#        28    0.000    0.000    0.000    0.000 _base.py:955(_set_artist_props)
#         4    0.000    0.000    0.000    0.000 _base.py:965(_gen_axes_patch)
#         4    0.000    0.000    0.003    0.001 _base.py:982(_gen_axes_spines)
#        20    0.000    0.000    0.003    0.000 _base.py:997(<genexpr>)
#        16    0.000    0.000    0.000    0.000 _binary.py:91(o32be)
#         2    0.000    0.000    0.000    0.000 _bootlocale.py:11(getpreferredencoding)
#       100    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         8    0.000    0.000    0.011    0.001 _core.py:1018(comp_data)
#         8    0.000    0.000    0.000    0.000 _core.py:1060(_get_axes)
#         8    0.000    0.000    0.001    0.000 _core.py:1075(_attach)
#         8    0.000    0.000    0.000    0.000 _core.py:1163(_log_scaled)
#         8    0.000    0.000    0.081    0.010 _core.py:1180(_add_axis_labels)
#        16    0.000    0.000    0.000    0.000 _core.py:1187(<genexpr>)
#         8    0.000    0.000    0.000    0.000 _core.py:1190(<genexpr>)
#         8    0.000    0.000    0.003    0.000 _core.py:1194(variable_type)
#         8    0.000    0.000    0.005    0.001 _core.py:263(__init__)
#        32    0.000    0.000    0.000    0.000 _core.py:41(__init__)
#         8    0.000    0.000    0.005    0.001 _core.py:488(__init__)
#        32    0.000    0.000    0.021    0.001 _core.py:50(map)
#         8    0.000    0.000    0.028    0.004 _core.py:602(__init__)
#         8    0.000    0.000    0.000    0.000 _core.py:617(get_semantics)
#         8    0.000    0.000    0.012    0.001 _core.py:655(assign_variables)
#         8    0.000    0.000    0.003    0.000 _core.py:673(<dictcomp>)
#        16    0.000    0.000    0.011    0.001 _core.py:80(__init__)
#         8    0.000    0.000    0.009    0.001 _core.py:823(_assign_variables_longform)
#         8    0.000    0.000    0.004    0.001 _core.py:929(<dictcomp>)
#        32    0.000    0.000    0.011    0.000 _core.py:937(iter_data)
#        16    0.000    0.000    0.000    0.000 _core.py:977(<listcomp>)
#         8    0.000    0.000    0.240    0.030 _decorators.py:30(inner_f)
#         8    0.000    0.000    0.003    0.000 _decorators.py:310(wrapper)
#         8    0.000    0.000    0.000    0.000 _decorators.py:45(<dictcomp>)
#       280    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#       280    0.000    0.000    0.001    0.000 _dtype.py:307(_name_includes_bit_suffix)
#       280    0.001    0.000    0.002    0.000 _dtype.py:321(_name_get)
#       100    0.042    0.000    0.167    0.002 _functional.py:53(adam)
#       252    0.000    0.000    0.000    0.000 _jit_internal.py:833(is_scripting)
#       364    0.001    0.000    0.009    0.000 _methods.py:106(_clip)
#       352    0.001    0.000    0.003    0.000 _methods.py:245(_ptp)
#      1860    0.001    0.000    0.006    0.000 _methods.py:37(_amax)
#       656    0.000    0.000    0.003    0.000 _methods.py:41(_amin)
#       472    0.000    0.000    0.003    0.000 _methods.py:45(_sum)
#       178    0.000    0.000    0.001    0.000 _methods.py:53(_any)
#       157    0.000    0.000    0.001    0.000 _methods.py:56(_all)
#       728    0.003    0.000    0.005    0.000 _methods.py:72(_clip_dep_is_scalar_nan)
#       728    0.000    0.000    0.001    0.000 _methods.py:82(_clip_dep_is_byte_swapped)
#       364    0.002    0.000    0.002    0.000 _methods.py:87(_clip_dep_invoke_with_casting)
#        38    0.000    0.000    0.000    0.000 _namedtensor_internals.py:10(check_serializing_named_tensor)
#        25    0.000    0.000    0.000    0.000 _pylab_helpers.py:106(get_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:111(_set_new_active_manager)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:124(set_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:34(get_fig_manager)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:79(destroy_all)
#         2    0.000    0.000    0.000    0.000 _pylab_helpers.py:96(get_all_fig_managers)
#       111    0.000    0.000    0.000    0.000 _reduction.py:7(get_enum)
#         8    0.000    0.000    0.005    0.001 _statistics.py:116(define_support)
#        16    0.000    0.000    0.007    0.000 _statistics.py:128(_fit)
#         8    0.000    0.000    0.065    0.008 _statistics.py:142(_eval_univariate)
#         8    0.000    0.000    0.065    0.008 _statistics.py:184(__call__)
#         8    0.000    0.000    0.000    0.000 _statistics.py:38(__init__)
#         8    0.000    0.000    0.001    0.000 _statistics.py:81(_define_support_grid)
#         8    0.000    0.000    0.005    0.001 _statistics.py:89(_define_support_univariate)
#         4    0.000    0.000    0.098    0.024 _subplots.py:18(__init__)
#         4    0.000    0.000    0.000    0.000 _subplots.py:83(get_subplotspec)
#         4    0.000    0.000    0.001    0.000 _subplots.py:95(update_params)
#       996    0.002    0.000    0.002    0.000 _ufunc_config.py:132(geterr)
#       996    0.002    0.000    0.005    0.000 _ufunc_config.py:32(seterr)
#       498    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__init__)
#       498    0.001    0.000    0.004    0.000 _ufunc_config.py:433(__enter__)
#       498    0.001    0.000    0.003    0.000 _ufunc_config.py:438(__exit__)
#        16    0.000    0.000    0.000    0.000 _util.py:216(_asarray_validated)
#         1    0.000    0.000    0.000    0.000 _util.py:5(isPath)
#        38    0.000    0.000    0.002    0.000 _utils.py:11(_type)
#        38    0.000    0.000    0.000    0.000 _utils.py:462(_get_device_index)
#        38    0.000    0.000    0.000    0.000 _utils.py:8(_get_device_index)
#        38    0.000    0.000    0.000    0.000 _utils.py:83(_get_async_or_non_blocking)
#        24    0.000    0.000    0.000    0.000 _validators.py:208(validate_bool_kwarg)
#         8    0.000    0.000    0.000    0.000 _validators.py:218(validate_axis_style_args)
#       153    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#      2489    0.001    0.000    0.003    0.000 abc.py:96(__instancecheck__)
#      1208    0.002    0.000    0.027    0.000 activation.py:101(forward)
#       311    0.000    0.000    0.009    0.000 activation.py:298(forward)
#       933    0.001    0.000    0.020    0.000 activation.py:713(forward)
#         4    0.000    0.000    0.000    0.000 activation.py:97(__init__)
#         2    0.000    0.000    0.000    0.000 adam.py:34(__init__)
#       100    0.007    0.000    0.183    0.002 adam.py:55(step)
#        32    0.000    0.000    0.001    0.000 algorithms.py:1534(_get_take_nd_function)
#        16    0.000    0.000    0.000    0.000 algorithms.py:1570(take)
#        32    0.000    0.000    0.002    0.000 algorithms.py:1661(take_nd)
#        16    0.000    0.000    0.001    0.000 array_ops.py:118(_na_arithmetic_op)
#        16    0.000    0.000    0.002    0.000 array_ops.py:194(comparison_op)
#        16    0.000    0.000    0.005    0.000 arraylike.py:27(__eq__)
#        56    0.000    0.000    0.000    0.000 arraysetops.py:136(_unpack_tuple)
#        56    0.000    0.000    0.000    0.000 arraysetops.py:144(_unique_dispatcher)
#        56    0.000    0.000    0.001    0.000 arraysetops.py:149(unique)
#        56    0.000    0.000    0.001    0.000 arraysetops.py:309(_unique1d)
#        28    0.000    0.000    0.000    0.000 arraysetops.py:342(_intersect1d_dispatcher)
#        28    0.000    0.000    0.001    0.000 arraysetops.py:347(intersect1d)
#         8    0.000    0.000    0.000    0.000 arraysetops.py:491(_in1d_dispatcher)
#         8    0.000    0.000    0.000    0.000 arraysetops.py:495(in1d)
#         8    0.000    0.000    0.000    0.000 arraysetops.py:608(_isin_dispatcher)
#         8    0.000    0.000    0.001    0.000 arraysetops.py:612(isin)
#        33    0.000    0.000    0.000    0.000 artist.py:1004(get_label)
#        20    0.000    0.000    0.000    0.000 artist.py:1008(set_label)
#         8    0.000    0.000    0.000    0.000 artist.py:1024(get_zorder)
#       180    0.000    0.000    0.000    0.000 artist.py:1028(set_zorder)
#      1120    0.000    0.000    0.000    0.000 artist.py:1043(sticky_edges)
#       230    0.001    0.000    0.002    0.000 artist.py:1065(update_from)
#       646    0.001    0.000    0.069    0.000 artist.py:1086(set)
#        32    0.000    0.000    0.000    0.000 artist.py:1094(<genexpr>)
#         8    0.000    0.000    0.000    0.000 artist.py:115(remove)
#        28    0.000    0.000    0.000    0.000 artist.py:1213(mouseover)
#        72    0.000    0.000    0.000    0.000 artist.py:160(have_units)
#       216    0.000    0.000    0.000    0.000 artist.py:163(<genexpr>)
#      3114    0.001    0.000    0.004    0.000 artist.py:165(convert_xunits)
#      3136    0.001    0.000    0.003    0.000 artist.py:177(convert_yunits)
#     19972    0.003    0.000    0.003    0.000 artist.py:189(axes)
#       715    0.000    0.000    0.000    0.000 artist.py:194(axes)
# 32285/22721    0.017    0.000    0.028    0.000 artist.py:213(stale)
#        80    0.000    0.000    0.000    0.000 artist.py:246(_get_clipping_extent_bbox)
#        68    0.000    0.000    0.016    0.000 artist.py:263(get_tightbbox)
#     836/2    0.002    0.000    0.408    0.204 artist.py:33(draw_wrapper)
#      2992    0.001    0.000    0.002    0.000 artist.py:332(pchanged)
#        36    0.000    0.000    0.000    0.000 artist.py:346(is_transform_set)
#       471    0.000    0.000    0.001    0.000 artist.py:354(set_transform)
#      1854    0.001    0.000    0.001    0.000 artist.py:367(get_transform)
#      5068    0.004    0.000    0.013    0.000 artist.py:52(_stale_axes_callback)
#       100    0.000    0.000    0.000    0.000 artist.py:557(get_url)
#       448    0.000    0.000    0.000    0.000 artist.py:571(get_gid)
#       182    0.000    0.000    0.000    0.000 artist.py:585(get_snap)
#         4    0.000    0.000    0.000    0.000 artist.py:596(set_snap)
#       182    0.000    0.000    0.000    0.000 artist.py:624(get_sketch_params)
#       314    0.000    0.000    0.000    0.000 artist.py:680(get_path_effects)
#         8    0.000    0.000    0.000    0.000 artist.py:683(get_figure)
#       581    0.001    0.000    0.001    0.000 artist.py:687(set_figure)
#       566    0.003    0.000    0.005    0.000 artist.py:69(__init__)
#        20    0.000    0.000    0.000    0.000 artist.py:711(set_clip_box)
#        80    0.001    0.000    0.009    0.000 artist.py:723(set_clip_path)
#       140    0.000    0.000    0.000    0.000 artist.py:785(get_alpha)
#      5369    0.001    0.000    0.001    0.000 artist.py:792(get_visible)
#     32293    0.004    0.000    0.004    0.000 artist.py:796(get_animated)
#       125    0.000    0.000    0.000    0.000 artist.py:800(get_in_layout)
#       148    0.000    0.000    0.000    0.000 artist.py:811(get_clip_on)
#       148    0.000    0.000    0.000    0.000 artist.py:815(get_clip_box)
#       164    0.000    0.000    0.000    0.000 artist.py:819(get_clip_path)
#        40    0.000    0.000    0.000    0.000 artist.py:833(set_clip_on)
#       314    0.000    0.000    0.003    0.000 artist.py:850(_set_gc_clip)
#      1672    0.000    0.000    0.000    0.000 artist.py:860(get_rasterized)
#      1672    0.000    0.000    0.000    0.000 artist.py:880(get_agg_filter)
#        82    0.000    0.000    0.000    0.000 artist.py:921(set_alpha)
#       535    0.000    0.000    0.001    0.000 artist.py:935(set_visible)
#         1    0.000    0.000    0.000    0.000 artist.py:959(set_in_layout)
#      1081    0.007    0.000    0.028    0.000 artist.py:972(update)
#       176    0.007    0.000    0.184    0.001 axis.py:1016(_update_ticks)
#       176    0.000    0.000    0.131    0.001 axis.py:1089(_get_tick_bboxes)
#       176    0.002    0.000    0.130    0.001 axis.py:1091(<listcomp>)
#       176    0.000    0.000    0.001    0.000 axis.py:1093(<listcomp>)
#        72    0.001    0.000    0.314    0.004 axis.py:1096(get_tightbbox)
#       144    0.000    0.000    0.004    0.000 axis.py:1121(<genexpr>)
#        72    0.001    0.000    0.002    0.000 axis.py:1141(<listcomp>)
#        16    0.000    0.000    0.171    0.011 axis.py:1156(draw)
#        16    0.000    0.000    0.000    0.000 axis.py:1193(get_label)
#        12    0.000    0.000    0.080    0.007 axis.py:1205(get_majorticklabels)
#        12    0.000    0.000    0.000    0.000 axis.py:1208(<listcomp>)
#        12    0.000    0.000    0.000    0.000 axis.py:1209(<listcomp>)
#        12    0.000    0.000    0.080    0.007 axis.py:1219(get_ticklabels)
#       188    0.000    0.000    0.042    0.000 axis.py:1281(get_majorticklocs)
#       176    0.002    0.000    0.038    0.000 axis.py:1285(get_minorticklocs)
#       176    0.000    0.000    0.000    0.000 axis.py:1298(<listcomp>)
#       364    0.001    0.000    0.011    0.000 axis.py:1333(_get_tick_label_size)
#        46    0.000    0.000    0.008    0.000 axis.py:1345(_copy_tick_props)
#        40    0.000    0.000    0.000    0.000 axis.py:1359(get_major_locator)
#       188    0.000    0.000    0.090    0.000 axis.py:1375(get_major_ticks)
#       176    0.000    0.000    0.000    0.000 axis.py:1388(get_minor_ticks)
#        16    0.000    0.000    0.042    0.003 axis.py:1401(grid)
#        16    0.000    0.000    0.000    0.000 axis.py:1433(<dictcomp>)
#        70    0.000    0.000    0.000    0.000 axis.py:145(<dictcomp>)
#        80    0.000    0.000    0.001    0.000 axis.py:1454(update_units)
#       216    0.000    0.000    0.000    0.000 axis.py:1509(have_units)
#       312    0.000    0.000    0.002    0.000 axis.py:1512(convert_units)
#        48    0.000    0.000    0.000    0.000 axis.py:1529(set_units)
#        20    0.000    0.000    0.000    0.000 axis.py:1549(set_label_text)
#        64    0.000    0.000    0.001    0.000 axis.py:1570(set_major_formatter)
#        64    0.000    0.000    0.001    0.000 axis.py:1596(set_minor_formatter)
#       128    0.000    0.000    0.001    0.000 axis.py:1610(_set_formatter)
#        64    0.000    0.000    0.001    0.000 axis.py:1636(set_major_locator)
#        64    0.000    0.000    0.001    0.000 axis.py:1652(set_minor_locator)
#        48    0.000    0.000    0.000    0.000 axis.py:1881(_get_ticks_position)
#        96    0.000    0.000    0.000    0.000 axis.py:1897(<genexpr>)
#        96    0.000    0.000    0.000    0.000 axis.py:1903(<genexpr>)
#        96    0.000    0.000    0.000    0.000 axis.py:1909(<genexpr>)
# 1436/1420    0.001    0.000    0.027    0.000 axis.py:1944(getter)
#        70    0.000    0.000    0.000    0.000 axis.py:196(_set_labelrotation)
#         4    0.000    0.000    0.004    0.001 axis.py:1972(__init__)
#        34    0.000    0.000    0.055    0.002 axis.py:2011(_get_tick)
#        68    0.000    0.000    0.124    0.002 axis.py:2032(_get_tick_boxes_siblings)
#        68    0.001    0.000    0.148    0.002 axis.py:2051(_update_label_position)
#        68    0.000    0.000    0.016    0.000 axis.py:2094(_update_offset_text_position)
#        70    0.000    0.000    0.000    0.000 axis.py:214(get_tick_padding)
#        48    0.000    0.000    0.001    0.000 axis.py:2204(get_ticks_position)
# ...
#    250553    0.025    0.000    0.025    0.000 {method 'append' of 'list' objects}
#      5200    0.624    0.000    0.624    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#       194    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'cleanup' of 'ImagingEncoder' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         8    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       302    0.001    0.000    0.001    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#       364    0.000    0.000    0.010    0.000 {method 'clip' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedWriter' objects}
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of 'pandas._libs.parsers.TextReader' objects}
#        16    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.001    0.001 {method 'copy' of 'ImagingCore' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#        25    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       464    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#      5745    0.005    0.000    0.005    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        34    0.002    0.000    0.002    0.000 {method 'copy_' of 'torch._C.FloatStorageBase' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy_' of 'torch._C.LongStorageBase' objects}
#       908    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#       204    0.032    0.000    0.032    0.000 {method 'cpu' of 'torch._C._TensorBase' objects}
#       224    0.001    0.000    0.001    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#        34    0.000    0.000    0.000    0.000 {method 'data_ptr' of 'torch._C.FloatStorageBase' objects}
#         4    0.000    0.000    0.000    0.000 {method 'data_ptr' of 'torch._C.LongStorageBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#       249    0.001    0.000    0.001    0.000 {method 'detach' of 'torch._C._TensorBase' objects}
#        32    0.000    0.000    0.000    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#      2538    0.001    0.000    0.001    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        12    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#        66    0.001    0.000    0.001    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#         8    0.003    0.000    0.003    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        83    0.004    0.000    0.006    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        66    0.001    0.000    0.002    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         2    0.000    0.000    0.001    0.001 {method 'dump' of '_pickle.Pickler' objects}
#        34    0.000    0.000    0.000    0.000 {method 'element_size' of 'torch._C.FloatStorageBase' objects}
#         4    0.000    0.000    0.000    0.000 {method 'element_size' of 'torch._C.LongStorageBase' objects}
#         2    0.039    0.019    0.039    0.019 {method 'encode' of 'ImagingEncoder' objects}
#         8    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#       241    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        96    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#         8    0.000    0.000    0.000    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#       132    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#       100    0.008    0.000    0.008    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'flush' of '_io.BufferedWriter' objects}
#         1    0.000    0.000    0.000    0.000 {method 'flush' of '_io.BytesIO' objects}
#       443    0.001    0.000    0.001    0.000 {method 'format' of 'str' objects}
#     61965    0.010    0.000    0.010    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        66    0.000    0.000    0.000    0.000 {method 'get_bitmap_offset' of 'matplotlib.ft2font.FT2Font' objects}
#       302    0.000    0.000    0.000    0.000 {method 'get_descent' of 'matplotlib.ft2font.FT2Font' objects}
#        68    0.000    0.000    0.000    0.000 {method 'get_device' of 'torch._C.CudaFloatStorageBase' objects}
#         8    0.000    0.000    0.000    0.000 {method 'get_device' of 'torch._C.CudaLongStorageBase' objects}
#        16    0.000    0.000    0.000    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#        56    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#       236    0.000    0.000    0.000    0.000 {method 'get_width_height' of 'matplotlib.ft2font.FT2Font' objects}
#         3    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        38    0.000    0.000    0.000    0.000 {method 'has_names' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         8    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        24    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        48    0.000    0.000    0.000    0.000 {method 'intersection' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 {method 'is_complex' of 'torch._C._TensorBase' objects}
#        46    0.000    0.000    0.000    0.000 {method 'is_floating_point' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'islower' of 'bytes' objects}
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#      1310    0.079    0.000    0.079    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#     16134    0.002    0.000    0.002    0.000 {method 'items' of 'collections.OrderedDict' objects}
#     29246    0.004    0.000    0.004    0.000 {method 'items' of 'dict' objects}
#        24    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         6    0.000    0.000    0.000    0.000 {method 'join' of 'bytes' objects}
#      2812    0.001    0.000    0.001    0.000 {method 'join' of 'str' objects}
#        19    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#      4907    0.001    0.000    0.001    0.000 {method 'lower' of 'str' objects}
#       604    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 {method 'manual_seed' of 'torch._C.Generator' objects}
#       789    0.001    0.000    0.001    0.000 {method 'match' of 're.Pattern' objects}
#      1860    0.001    0.000    0.007    0.000 {method 'max' of 'numpy.ndarray' objects}
#       656    0.001    0.000    0.004    0.000 {method 'min' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#        16    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#      3400    0.037    0.000    0.037    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#       396    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#       204    0.001    0.000    0.001    0.000 {method 'numpy' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pixel_access' of 'ImagingCore' objects}
#         8    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#     10195    0.002    0.000    0.002    0.000 {method 'pop' of 'dict' objects}
#        11    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        40    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#       200    0.005    0.000    0.005    0.000 {method 'random_' of 'torch._C._TensorBase' objects}
#       359    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.001    0.001 {method 'read' of 'pandas._libs.parsers.TextReader' objects}
#     15691    0.057    0.000    0.057    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         4    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        81    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#      5257    0.001    0.000    0.001    0.000 {method 'replace' of 'str' objects}
#      1682    0.001    0.000    0.001    0.000 {method 'requires_grad_' of 'torch._C._TensorBase' objects}
#      2982    0.003    0.000    0.003    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#      1204    0.005    0.000    0.005    0.000 {method 'round' of 'numpy.ndarray' objects}
#       172    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       100    0.168    0.002    0.168    0.002 {method 'run_backward' of 'torch._C._EngineBase' objects}
#        32    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#      5232    0.529    0.000    0.529    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
#       302    0.000    0.000    0.000    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#       302    0.033    0.000    0.033    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#        72    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingEncoder' objects}
#        68    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C.CudaFloatStorageBase' objects}
#         8    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C.CudaLongStorageBase' objects}
#        34    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C.FloatStorageBase' objects}
#         4    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C.LongStorageBase' objects}
#       850    0.001    0.000    0.001    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#        21    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#      2700    0.692    0.000    0.692    0.000 {method 'sort' of 'numpy.ndarray' objects}
#      7891    0.001    0.000    0.001    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#      1700    0.021    0.000    0.021    0.000 {method 'sqrt' of 'torch._C._TensorBase' objects}
#        32    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#      3859    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#        38    0.000    0.000    0.000    0.000 {method 'storage' of 'torch._C._TensorBase' objects}
#        38    0.000    0.000    0.000    0.000 {method 'storage_offset' of 'torch._C._TensorBase' objects}
#        38    0.000    0.000    0.000    0.000 {method 'stride' of 'torch._C._TensorBase' objects}
#      7497    0.003    0.000    0.003    0.000 {method 'sub' of 're.Pattern' objects}
#       472    0.000    0.000    0.003    0.000 {method 'sum' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#       448    0.129    0.000    0.129    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#         8    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#       100    0.007    0.000    0.007    0.000 {method 'tolist' of 'torch._C._TensorBase' objects}
#        32    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'uniform_' of 'torch._C._TensorBase' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#       618    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        13    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#     50997    0.007    0.000    0.007    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      1251    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#      2116    0.002    0.000    0.002    0.000 {method 'values' of 'mappingproxy' objects}
#        48    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.generic' objects}
#        64    0.000    0.000    0.001    0.000 {method 'view' of 'numpy.ndarray' objects}
#        19    0.000    0.000    0.000    0.000 {method 'write' of '_io.BytesIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 {method 'writerow' of '_csv.writer' objects}
#         1    0.001    0.001    0.001    0.001 {method 'writerows' of '_csv.writer' objects}
#      1694    0.011    0.000    0.011    0.000 {method 'zero_' of 'torch._C._TensorBase' objects}
#        40    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#        38    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#        32    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#        16    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis0_float32_float32}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis0_float64_float64}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.array_equivalent_object}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.clean_index_list}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_datetimelike_array}
#        92    0.001    0.000    0.001    0.000 {pandas._libs.lib.infer_dtype}
#        41    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#       129    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#        17    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#       117    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#       596    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_list_like}
#       455    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#       120    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
