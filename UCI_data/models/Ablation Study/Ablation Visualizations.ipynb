# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.99618, 0.99229, 0.98724, 1, 0.99546, 1, 0.96867])

fig = plt.figure(figsize = [7, 5])
ax = plt.subplot(111)
ax.set_xlim(2, 10)

ax.spines['right'].set_color((.8,.8,.8))
ax.spines['top'].set_color((.8,.8,.8))

ax.grid('on')

plt.scatter(x, y, color = 'blue', label = 'Activity')

x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.98145, 0.95306, 0.94943, 0.83844, 0.89650, 0.89964, 0.84856])

plt.scatter(x, y, color = 'green', label = 'Subject')

x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.95716, 0.87089, 0.86222, 0.81903, 0.85865, 0.85293, 0.87493])

plt.scatter(x, y, color = 'red', label = 'Holistic')

plt.legend(title = 'Legend')
plt.xlabel('Subject Count')
plt.ylabel('Weighted Average F-1 Score')
plt.title('Benchmark Scores')

plt.show()

# %%
x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([1, 1, 1, 1, 1, 1, 1])

fig = plt.figure(figsize = [7, 5])
ax = plt.subplot(111)
ax.set_xlim(2, 10)

ax.spines['right'].set_color((.8,.8,.8))
ax.spines['top'].set_color((.8,.8,.8))

ax.grid('on')

plt.scatter(x, y, color = 'blue', label = 'Activity')

x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.97450, 0.98745, 0.81663, 0.78100, 0.77059, 0.89123, 0.90378])

plt.scatter(x, y, color = 'green', label = 'Subject')

x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.93814, 0.70216, 0.74558, 0.76194, 0.76597, 0.75923, 0.78877])

plt.scatter(x, y, color = 'red', label = 'Holistic')

plt.legend(title = 'Legend')
plt.xlabel('Subject Count')
plt.ylabel('Weighted Average F-1 Score')
plt.title('Unified GAN Scores')

plt.show()

# %%
x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([1, 0.99167, 0.9732, 0.99444, 0.99047, 0.99167, 0.94815])

fig = plt.figure(figsize = [7, 5])
ax = plt.subplot(111)
ax.set_xlim(2, 10)

ax.spines['right'].set_color((.8,.8,.8))
ax.spines['top'].set_color((.8,.8,.8))

ax.grid('on')

plt.scatter(x, y, color = 'blue', label = 'Activity')

x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.83836, 0.71279, 0.70076, 0.70517, 0.67002, 0.69781, 0.56061])

plt.scatter(x, y, color = 'green', label = 'Subject')

x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.85455, 0.70216, 0.67139, 0.63683, 0.66923, 0.69475, 0.61566])

plt.scatter(x, y, color = 'red', label = 'Holistic')

plt.legend(title = 'Legend')
plt.xlabel('Subject Count')
plt.ylabel('Weighted Average F-1 Score')
plt.title('Stratified GAN Scores')

plt.show()

# %%
x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.00382, 0.00771, 0.01276, 0, 0.00454, 0, 0.03133])

fig = plt.figure(figsize = [7, 5])
ax = plt.subplot(111)
ax.set_xlim(2, 10)

ax.spines['right'].set_color((.8,.8,.8))
ax.spines['top'].set_color((.8,.8,.8))

ax.grid('on')

plt.scatter(x, y, color = 'blue', label = 'Unified Delta')

x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.00382, 0.00062, 0.01392, 0.00556, 0.00499, 0.00833, 0.02052])

plt.scatter(x, y, color = 'red', label = 'Stratified Delta')

plt.legend(title = 'Legend')
plt.xlabel('Subject Count')
plt.ylabel('Weighted Average F-1 Score Delta')
plt.title('Activity Delta Scores')
plt.ylim(-0.01, 0.05)

plt.show()

# %%
x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.00695, 0.03439, 0.1328, 0.05744, 0.12591, 0.089123, 0.05522])

fig = plt.figure(figsize = [7, 5])
ax = plt.subplot(111)
ax.set_xlim(2, 10)

ax.spines['right'].set_color((.8,.8,.8))
ax.spines['top'].set_color((.8,.8,.8))

ax.grid('on')

plt.scatter(x, y, color = 'blue', label = 'Unified Delta')

x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.14309, 0.24027, 0.24867, 0.13327, 0.22648, 0.20183, 0.28795])

plt.scatter(x, y, color = 'red', label = 'Stratified Delta')

plt.legend(title = 'Legend')
plt.xlabel('Subject Count')
plt.ylabel('Weighted Average F-1 Score Delta')
plt.title('Subject Delta Scores')
plt.ylim(0, 0.35)

plt.show()

# %%
x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.01902, 0.01868, 0.11664, 0.05709, 0.08908, 0.0937, 0.08616])

fig = plt.figure(figsize = [7, 5])
ax = plt.subplot(111)
ax.set_xlim(2, 10)

ax.spines['right'].set_color((.8,.8,.8))
ax.spines['top'].set_color((.8,.8,.8))

ax.grid('on')

plt.scatter(x, y, color = 'blue', label = 'Unified Delta')

x = np.asarray([3, 4, 5, 6, 7, 8, 9])
y = np.asarray([0.10261, 0.16873, 0.19083, 0.18220, 0.18942, 0.15818, 0.25927])

plt.scatter(x, y, color = 'red', label = 'Stratified Delta')

plt.legend(title = 'Legend')
plt.xlabel('Subject Count')
plt.ylabel('Weighted Average F-1 Score Delta')
plt.title('Holistic Delta Scores')
plt.ylim(0, 0.3)

plt.show()
